# %%
# %reset -f
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %load main.py

# %%
#%%writefile main.py

import numpy as np
import pandas as pd
import pickle
import os
import json
import sklearn
from sklearn import metrics

def saveobj(datain,namein='output'):    
    """
    Purpose: 
        Serialize and store objects
    Input:
        datain: Object to be stored
        namein: Path of to-be-stored object
    Output:
        None
    Comments:
        N/A
    """
    with open(namein, 'wb') as fp:
        pickle.dump(datain, fp, protocol=pickle.HIGHEST_PROTOCOL)

def loadobj(namein):
    """
    Purpose: 
        Read and deserialize objects
    Input:
        namein: Path of to-be-read object
    Output:
        Read and deserialized object
    Comments:
        N/A
    """
    curdir=os.path.dirname(__file__)
    newpath=os.path.join(curdir,namein)
    
    with open(newpath, 'rb') as fp:
        data = pickle.load(fp)
        return data

def savejson(datain,namein='output'):
    with open(namein+'.json', 'w') as fp:
        json.dump(datain, fp)

def loadjson(namein):
    with open(namein+'.json', 'r') as fp:
        return json.load(fp)

def getmappingfile():
    """
    Purpose: 
        Return bidirectional (icd9 to icd10 and icd10 to icd9 combined) icd mapping file in pandas dataframe format
        Mapping is based on Center for Medicare and Medicaid Services General Equivalence Mappings version 2018 [https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html]
    Input:
        None
    Output:
        bidirectional icd mapping file
    Comments:
        A diagnosis code may be mapped to none, one, or multiple diagnosis codes
        Columns for mapping file are as follows:
            source: source icd code
            target: converted icd code
            flag: 
            Approximate
            No Map
            Combination
            Scenario
            Choice List
            sourcetype: icd9 or icd10
            targettype: icd10 or icd9
    """
    curdir=os.path.dirname(__file__)
    newpath=os.path.join(curdir,'mapdf.pickle')
    return pd.read_pickle(newpath)

def getelixhauser_comorbidities():
    """
    Purpose: 
        Returns dictionary for elixhauser comorbidities based on Quan et al (2005):
            Quan H, Sundararajan V, Halfon P, Fong A, Burnand B, Luthi JC, Saunders LD, Beck CA, Feasby TE, Ghali WA. 
            Coding algorithms for defining comorbidities in ICD-9-CM and ICD-10 administrative data. 
            Medical care. 2005 Nov 1:1130-9.
        Scores for elixhauser comorbidity index is based on van Walraven et al (2009):
            van Walraven C, Austin PC, Jennings A, Quan H, Forster AJ. 
            A modification of the Elixhauser comorbidity measures into a point system for hospital death using administrative data. 
            Medical care. 2009 Jun 1:626-33.
    Input:
        N/A
    Output:
        dictionary containing icd9 codes, icd10 codes, and elixhauser comorbidity index score for each comorbidity in the elixhauser comorbidity index.
    Comments:
        N/A
    """
    return loadjson('elixhauser_comorbidities')

def checkcols(datain,idcolumn,icdcolumn):
    """
    Purpose: 
        Ensure that id column and icd column are both present in the dataframe
    Input:
        datain: diagnosis code dataframe in long format
        idcolumn: name of the patient/encounter identifier column
        icdcolumn: name of the icd code column
    Output:
        True if both id column and icd column are both present in the dataframe, False otherwise
    Comments:
        N/A
    """
    if icdcolumn is None:
        print('please specify the icd column')
        return False
    if icdcolumn not in list(datain.columns):
        print('column ['+str(icdcolumn)+'] not found in columns: '+str(datain.columns))
        return False
    if idcolumn is None:
        print('please specify the id column')
        return False
    if idcolumn not in list(datain.columns):
        print('column ['+str(idcolumn)+'] not found in columns: '+str(datain.columns))
        return False
    return True

def cleanicd(dfin,icdcolumn):
    """
    Purpose: 
        Strip whitespace and period from icd codes
    Input:
        dfin: diagnosis code dataframe in long format
        icdcolumn: name of the icd code column
    Output:
        Returns diagnosis dataframe with cleaned up icd code column
    Comments:
        Assuming checkcols has already been performed prior to running this function
    """
    dfin[icdcolumn] = dfin[icdcolumn].astype(str).str.replace('.', '').str.replace(' ','')
    return dfin

def icdconv(datain, idcolumn=None, icdcolumn=None, typecol='ICDtype'):
    """
    Purpose: 
        Convert icd9 to icd10 codes, as well as icd10 to icd9 codes and return a diagnosis dataframe that includes both the original code and the converted code in long format
    Input:
        datain: diagnosis code dataframe in long format
        idcolumn: name of the patient/encounter identifier column
        icdcolumn: name of the icd code column
        typecol: column that indicates if the diagnosis code is in icd9 or icd10
    Output:
        Diagnosis dataframe that includes both the original code and the converted code in long format
    Comments:
        N/A
    """
    mapdf = getmappingfile()
    unqcodes = list(mapdf.source.unique())

    #if pandas dataframe
    if type(datain) == pd.core.frame.DataFrame:
        if checkcols(datain, idcolumn, icdcolumn) == False:
            return None
        dataout_original = datain.loc[:, [idcolumn, icdcolumn]].copy()

        dataout_original=cleanicd(dataout_original,icdcolumn)
        
        dataout_original[typecol] = None
        dataout_original = dataout_original.merge(
            mapdf.loc[:, ['source', 'target', 'sourcetype', 'targettype']],
            left_on=icdcolumn,
            right_on='source',
            how='left')
        #display(dataout_original)
        for icdcode in dataout_original.loc[dataout_original['sourcetype']
                                            .isnull(), icdcolumn]:
            print('Underspecified or unidentifiable diagnosis code: ' + str(icdcode))

        #dataout_original = dataout_original.loc[(dataout_original['sourcetype'].notnull()), :]
        dataout_converted = dataout_original.loc[(dataout_original[
            'target'].notnull()), [idcolumn, 'target', 'targettype']]
        dataout_converted.columns = [idcolumn, icdcolumn, typecol]
        dataout_original = dataout_original.loc[:, [
            idcolumn, icdcolumn, 'sourcetype'
        ]].drop_duplicates()
        dataout_original.columns = [idcolumn, icdcolumn, typecol]
        return pd.concat([dataout_original, dataout_converted], axis=0)   
    
    

    
    
def icdtophenotype(datain,idcolumn=None,icdcolumn=None,featurematrix=False):
    """
    Purpose: 
        Map icd codes to Elixhauser comorbidites (Quan et al. 2005) and return comorbidity dataframe
    Input:
        datain: diagnosis code dataframe in long format
        idcolumn: name of the patient/encounter identifier column
        icdcolumn: name of the icd code column
        featurematrix: if False, returns a long-format diagnosis dataframe, if True, returns a binary feature-matrix-format diagnosis dataframe
    Output:
        Depending on the featurematrix parameter, either a long-format diagnosis dataframe or a binary feature-matrix-format diagnosis dataframe
    Comments:
        N/A
    """
    elixhauser_comorbidities=getelixhauser_comorbidities()
    
    if checkcols(datain, idcolumn, icdcolumn) == False:
        return None
    
    dataout=datain.copy()
    dataout=cleanicd(dataout,icdcolumn)
    dataout['comorbidity']=None
    
    for como in elixhauser_comorbidities:
        print('Currently processing: '+como+'                                                         ',end="\r",flush=True)
        
        dataout.loc[dataout[icdcolumn].str.startswith(tuple(elixhauser_comorbidities[como]['icd9']+elixhauser_comorbidities[como]['icd10']),na=False),'comorbidity']=como
        
    
    if not featurematrix:
        return dataout
    
    dataout=pd.concat([dataout[idcolumn],pd.get_dummies(dataout['comorbidity'])],axis=1).groupby(idcolumn).max()
    
    return dataout
    
    

def comorbidityindex(datain,scorecol='Elixhauser_Comorbidity_Score',scoreonly=False):
    """
    Purpose: 
        Return Elixhauser Index Score dataframe
    Input:
        datain: phenotype featurematrix
        scorecol: name of the Elixhauser Index Score column in the returned dataframe
        scoreonly: if True, only returns the Elixhauser Index Score, if False, returns the full binary comorbidity dataframe in addition to the Elixhauser Index Score
    Output:
        Elixhauser Index Score dataframe
    Comments:
        N/A
    """

    dataout=datain.copy()
    
    if dataout is None:
        return None
    
    elixhauser_comorbidities=getelixhauser_comorbidities()
    for como in list(dataout.columns):
        dataout.loc[:,como]*=elixhauser_comorbidities[como]['score']
    
    dataout[scorecol]=dataout.sum(axis=1)
    if scoreonly:
        return dataout.loc[:,[scorecol]]
    
    return dataout
    

def comorbiditypipeline(datain, idcolumn=None, icdcolumn=None,scorecol='Elixhauser_Comorbidity_Score'):
    """
    Purpose: 
        Return Elixhauser Index Score dataframe
    Input:
        datain: phenotype featurematrix
        scorecol: name of the Elixhauser Index Score column in the returned dataframe
        scoreonly: if True, only returns the Elixhauser Index Score, if False, returns the full binary comorbidity dataframe in addition to the Elixhauser Index Score
    Output:
        Elixhauser Index Score dataframe
    Comments:
        N/A
    """
    convdiagdf=icdconv(datain, idcolumn=idcolumn, icdcolumn=icdcolumn, typecol='ICDtype')
    phenodf=icdtophenotype(convdiagdf,idcolumn=idcolumn,icdcolumn=icdcolumn,featurematrix=True)
    #display(phenodf.sum(axis=0))
    comodf=comorbidityindex(phenodf,scorecol=scorecol,scoreonly=True)
    return pd.concat([phenodf,comodf],axis=1)

#NDC to RxNORM to Drug Class
def ndc2rxcui(df_med,col_ndc='ndc'):
    print('Converting NDC to RXCUI')
    output=[]
    ndclist=df_med[col_ndc].unique()
    lenndc = len(ndclist)
    for i in range(0,len(ndclist)):
        print('{}/{}, {:.2f}% complete'.format((i+1),lenndc,(i+1)/lenndc*100), end='\r', flush=True)
        curndc=ndclist[i]
        r=requests.get('https://rxnav.nlm.nih.gov/REST/ndcstatus.json?ndc='+str(curndc)).json()['ndcStatus']
        if 'ndcHistory' in r:
            for entry in r['ndcHistory']:
                output.append({
                    'ndc':curndc,
                    'rxcui':entry['activeRxcui'],
                    'start':pd.to_datetime(entry['startDate']+'01'),
                    'end':pd.to_datetime(entry['endDate']+'01'),
                })
        else:
            print('NDC code [{}] was not able to be mapped to rxcui'.format(curndc))
        time.sleep(1/20)
    output=pd.DataFrame(output).replace({r'^\s*$':None}, regex=True).dropna()
    return output
def rxcui2class(df_mapin,getname=True):
    print('Converting rxcui to drug class')
    rxcuilist=df_mapin['rxcui'].unique()
    lenrxcui=len(rxcuilist)
    output=[]
    
    identifier='classId'
    if getname:
        identifier='className'
    
    for i in range(0,lenrxcui):
        print('{}/{}, {:.2f}% complete'.format((i+1),lenrxcui,(i+1)/lenrxcui*100), end='\r', flush=True)
        currxcui=rxcuilist[i]
        r=requests.get('https://rxnav.nlm.nih.gov/REST/rxclass/class/byRxcui.json?rxcui='+str(currxcui)).json()

        if 'rxclassDrugInfoList' in r:
            tempdict={'rxcui':currxcui}
            for curclass in r['rxclassDrugInfoList']['rxclassDrugInfo']:
                classtype=curclass['relaSource']+'_'+curclass['rxclassMinConceptItem']['classType']
                if classtype not in tempdict:
                    tempdict[classtype]=set([curclass['rxclassMinConceptItem'][identifier]])
                else:
                    tempdict[classtype].add(curclass['rxclassMinConceptItem'][identifier])
            output.append(tempdict)
        else:
            print('rxcui [{}] was not able to be mapped to drug class'.format(currxcui))
        time.sleep(1/20)
    return pd.DataFrame(output)
def ndc2class(df_med,col_ndc='ndc',getname=True,indexcol='ROWID',timecol='TIME'):
    map1=ndc2rxcui(df_med,col_ndc=col_ndc)
    map2=rxcui2class(map1,getname=getname)

    newmed=df_med.copy()
    
    #merge maps to go from ndc to rxnorm to class
    fullmap=map1.merge(map2,how='left',on='rxcui')
    
    #merge medication dataframe to full map
    temp=newmed.merge(fullmap,how='left',left_on=col_ndc,right_on='ndc')
    
    #filter based on start and end date
    temp=temp.loc[(temp[timecol]>=temp.start) & (temp[timecol] <=temp.end),:]
    
    #if multiple rxcui per ndc, take the one with the later end date
    temp=temp.sort_values('end')
    temp=temp.drop_duplicates(subset=df_med.columns,keep='last')

    #if no rxcui exist for ndc given the time range, try to just take the latest rxcui
    temp=pd.concat([temp,newmed.loc[~newmed[indexcol].isin(temp[indexcol]),:].merge(fullmap.sort_values(by='end').drop_duplicates(subset='ndc',keep='last'),how='left',left_on='NDC',right_on='ndc')],axis=0)
    temp=temp.sort_values(by=indexcol)
    return temp

# similar to sklearn.model_selection.cross_val_score but supports multiple 
def cvmultiscore(model,x,y,scorelist=[sklearn.metrics.accuracy_score,sklearn.metrics.brier_score_loss,sklearn.metrics.f1_score,sklearn.metrics.log_loss,sklearn.metrics.precision_score,sklearn.metrics.recall_score,sklearn.metrics.roc_auc_score],cv=5):
    plt.rcParams['figure.figsize']=[5.,5.]
    splitter=sklearn.model_selection.StratifiedKFold(n_splits=cv,shuffle=True)
    output=[]
    for train,test in splitter.split(x,y):
        
        model.fit(x.iloc[train],y.iloc[train])
        
        trainypred=model.predict_proba(x.iloc[train])[:,1]
        
        fpr, tpr, thresholds = sklearn.metrics.roc_curve(y.iloc[train],trainypred)
        plt.plot(fpr,tpr,'b--')
        
        
        ypred=model.predict_proba(x.iloc[test])[:,1]
        tempdict={}
        for score in scorelist:
            tempdict[score.__name__]=score(y.iloc[test], ypred)
        fpr, tpr, thresholds = sklearn.metrics.roc_curve(y.iloc[test],ypred)
        plt.plot(fpr,tpr,'r--')
        
        
        output.append(tempdict)
    plt.show()
    return pd.DataFrame(output)

# %% [markdown]
# # USE CASES

# %%
import pandas as pd
import numpy as np
import os
import requests
import time

#load icd 9 to icd 10 mapping file
#https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html
def load_icd9to10():
    icd9to10 = pd.read_csv(os.path.join(os.getcwd(),'2018_I9gem.txt'),delim_whitespace=True,header=None,dtype=str)
    icd9to10.columns=['icd9','icd10','flag']
    return icd9to10

#load icd 10 to icd 9 mapping file
#https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html
def load_icd10to9():
    icd10to9 = pd.read_csv(os.path.join(os.getcwd(),'2018_I10gem.txt'),delim_whitespace=True,header=None,dtype=str)
    icd10to9.columns=['icd10','icd9','flag']
    return icd10to9

#convert icd 9 to 10, or 10 to 9
#https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html
def icdconvert(df,col_icd='icd',icd_version=9):
    if icd_version==9:
        source='icd9'
        target='icd10'
        df_gem=load_icd9to10()
    elif icd_version==10:
        source='icd10'
        target='icd9'
        df_gem=load_icd10to9()
    else:
        print('invalid icd version {}, please set curicd to 9 or 10'.format(icd_version))
        return None
    
    print('Comment: because of the discrepancy between icd9 and icd10, diagnosis codes may be mapped to many codes or no codes')
    
    output=df.merge(df_gem,how='left',left_on=col_icd,right_on=source)
    print('{:.2f}% mapped'.format(output[target].notnull().mean()*100))
    if 'flag' in output.columns:
        output.drop('flag',axis=1,inplace=True)
    if col_icd!=source in output.columns:
        output.drop(source,axis=1,inplace=True)
    
    return output

# load Elixhauser comorbidities mapping file
#Quan H, Sundararajan V, Halfon P, Fong A, Burnand B, Luthi JC, Saunders LD, Beck CA, Feasby TE, Ghali WA. 
#Coding algorithms for defining comorbidities in ICD-9-CM and ICD-10 administrative data. 
#Medical care. 2005 Nov 1:1130-9.
def loadelixcomo():
    elixcomo = pd.read_csv('Elixhauser_Comorbidities.csv').iloc[:,1:]
    return elixcomo

#convert icd 9 or 10 to Elixhauser Comorbidities
def icdtoelixcomo(df,col_icd):
    elixcomo = loadelixcomo()
    unqcomos = elixcomo['Comorbidity'].unique()
    df['ElixComo']=None
    df['ElixComoScore']=None
    for como in unqcomos:
        icdlist = tuple(elixcomo.loc[elixcomo['Comorbidity']==como,'ICD'])
        comoidx = df[col_icd].str.startswith(icdlist,na=False)
        df.loc[comoidx,'ElixComo']=como
        df.loc[comoidx,'ElixComoScore']=elixcomo.loc[elixcomo.Comorbidity==como,'Score'].values[0]
    return df
  

# score patients based on elixhauser comorbidities
#van Walraven C, Austin PC, Jennings A, Quan H, Forster AJ. 
#A modification of the Elixhauser comorbidity measures into a point system for hospital death using administrative data. 
#Medical care. 2009 Jun 1:626-33.
def elixcomoscore(df,col_icd,col_id):
    output = icdtoelixcomo(df,col_icd)
    output = output.loc[output['ElixComo'].notnull(),:]
    output = output.loc[:,[col_id,'ElixComo','ElixComoScore']]
    output = output.drop_duplicates()
    output = pd.DataFrame(output.groupby(col_id)['ElixComoScore'].sum()).reset_index()
    output = output.merge(df.loc[:,[col_id]].drop_duplicates(),how='outer',left_on=col_id,right_on=col_id).fillna(0.)
    return output
    
    
# load mapping file from icd9 to Chronic Condition Indicator (CCI)
#https://www.hcup-us.ahrq.gov/toolssoftware/chronic/chronic.jsp
def load_cci9():
    cci9 = pd.read_csv(os.path.join(os.getcwd(),'cci2015.csv'),skiprows=1)
    cci9.columns = [i.strip('\'') for i in cci9.columns]
    
    for col in cci9.columns:
        cci9.loc[:,col] = cci9[col].str.strip('\'')
    cci9 = cci9.replace(r'^\s*$', np.nan, regex=True)
    cci9.columns=[i.replace('CATEGORY DESCRIPTION','CHRONIC') for i in cci9.columns]

    dict_bodysystem=[
        ('1' ,'Infectious and parasitic disease'),
        ('2' ,'Neoplasms'),
        ('3' ,'Endocrine, nutritional, and metabolic diseases and immunity disorders'),
        ('4' ,'Diseases of blood and blood-forming organs'),
        ('5' ,'Mental disorders'),
        ('6' ,'Diseases of the nervous system and sense organs'),
        ('7' ,'Diseases of the circulatory system'),
        ('8' ,'Diseases of the respiratory system'),
        ('9' ,'Diseases of the digestive system'),
        ('10','Diseases of the genitourinary system'),
        ('11','Complications of pregnancy, childbirth, and the puerperium'),
        ('12','Diseases of the skin and subcutaneous tissue'),
        ('13','Diseases of the musculoskeletal system'),
        ('14','Congenital anomalies'),
        ('15','Certain conditions originating in the perinatal period'),
        ('16','Symptoms, signs, and ill-defined conditions'),
        ('17','Injury and poisoning'),
        ('18','Factors influencing health status and contact with health service'),
    ]
    
    cci9 = cci9.merge(pd.DataFrame(dict_bodysystem,columns=['BODY SYSTEM','BODY SYSTEM DESCRIPTION']),how='left',on='BODY SYSTEM')
    
    cci9.loc[:,'ICD-9-CM CODE'] = cci9['ICD-9-CM CODE'].str.replace(' ','')
    
    return cci9

#convert icd9 to CCI
def icd9tocci(df,col_icd='icd9'):
    cci9 = load_cci9()
    return df.merge(cci9,how='left',left_on=col_icd,right_on='ICD-9-CM CODE')
    
    
    

# load mapping file from icd10 to Chronic Condition Indicator (CCI)
#https://www.hcup-us.ahrq.gov/toolssoftware/chronic_icd10/chronic_icd10.jsp
def load_cci10():
    
    cci10 = pd.read_csv(os.path.join(os.getcwd(),'cci_icd10cm_2019_1.csv'))
    
    cci10.columns = [i.strip('\'') for i in cci10.columns]
    
    for col in cci10.columns:
        cci10.loc[:,col] = cci10[col].str.strip('\'')
    cci10 = cci10.replace(r'^\s*$', np.nan, regex=True)
    cci10.columns = [i.replace('CHRONIC INDICATOR','CHRONIC') for i in cci10.columns]
    
    dict_bodysystem = [
        ('1','Infectious and parasitic disease'),
        ('2','Neoplasms'),
        ('3','Endocrine, nutritional, and metabolic diseases and immunity disorders'),
        ('4','Diseases of blood and blood-forming organs'),
        ('5','Mental disorders'),
        ('6','Diseases of the nervous system and sense organs'),
        ('7','Diseases of the circulatory system'),
        ('8','Diseases of the respiratory system'),
        ('9','Diseases of the digestive system'),
        ('10','Diseases of the genitourinary system'),
        ('11','Complications of pregnancy, childbirth, and the puerperium'),
        ('12','Diseases of the skin and subcutaneous tissue'),
        ('13','Diseases of the musculoskeletal system'),
        ('14','Congenital anomalies'),
        ('15','Certain conditions originating in the perinatal period'),
        ('16','Symptoms, signs, and ill-defined conditions'),
        ('17','Injury and poisoning'),
        ('18','Factors influencing health status and contact with health services'),
    ]
    
    cci10 = cci10.merge(pd.DataFrame(dict_bodysystem,columns=['BODY SYSTEM','BODY SYSTEM DESCRIPTION']),how='left',on='BODY SYSTEM')
    
    cci10.loc[:,'ICD-10-CM CODE'] = cci10['ICD-10-CM CODE'].str.replace(' ','')
    
    return cci10

#convert icd10 to CCI
def icd10tocci(df,col_icd='icd10'):
    cci10 = load_cci10()
    return df.merge(cci10,how='left',left_on=col_icd,right_on='ICD-10-CM CODE')

# load mapping file from icd9 to Clinical Classification Software (CCS)
#https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp
def load_ccs9():
    ccs9 = pd.read_csv(os.path.join(os.getcwd(),'$dxref 2015.csv'))
    ccs9 = ccs9.reset_index()
    for col in ccs9.columns:
        ccs9.loc[:,col]=ccs9[col].str.strip('\'')
    ccs9.columns=ccs9.iloc[0,:]
    ccs9 = ccs9.iloc[1:,:]
    ccs9 = ccs9.replace(r'^\s*$', np.nan, regex=True)
    ccs9 = ccs9.loc[ccs9['ICD-9-CM CODE'].notnull(),:]
    ccs9.loc[:,'ICD-9-CM CODE'] = ccs9['ICD-9-CM CODE'].str.replace(' ','')
    ccs9.loc[:,'CCS CATEGORY'] = ccs9['CCS CATEGORY'].str.replace(' ','')
    ccs9 = ccs9.iloc[:,0:4]    
    ccs9_labels = pd.read_csv(os.path.join(os.getcwd(),'dxlabel 2015.csv'))
    ccs9 = ccs9.merge(ccs9_labels,how='left',left_on='CCS CATEGORY',right_on='CCS DIAGNOSIS CATEGORIES')
    ccs9.drop('CCS CATEGORY DESCRIPTION',axis=1,inplace=True)
    ccs9.drop('CCS DIAGNOSIS CATEGORIES',axis=1,inplace=True)
    ccs9.columns = [i.replace('CCS DIAGNOSIS CATEGORIES LABELS','CCS CATEGORY DESCRIPTION') for i in ccs9.columns]
    return ccs9

#https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp
def icd9toccs(df,col_icd='icd9'):
    ccs9 = load_ccs9()
    output = df.merge(ccs9,how='left',left_on=col_icd,right_on='ICD-9-CM CODE')
    if col_icd!='ICD-9-CM CODE':
        output.drop('ICD-9-CM CODE',axis=1,inplace=True)
    return output

# load mapping file from icd10 to Clinical Classification Software (CCS)
#https://www.hcup-us.ahrq.gov/toolssoftware/ccs10/ccs10.jsp
def load_ccs10():
    ccs10 = pd.read_csv(os.path.join(os.getcwd(),'ccs_dx_icd10cm_2019_1.csv'))
    ccs10.columns=[i.strip('\'') for i in ccs10.columns]
    for col in ccs10.columns:
        ccs10.loc[:,col]=ccs10[col].str.strip('\'')
    ccs10 = ccs10.replace(r'^\s*$', np.nan, regex=True)
    ccs10.loc[:,'ICD-10-CM CODE'] = ccs10['ICD-10-CM CODE'].str.replace(' ','')
    ccs10=ccs10.iloc[:,0:4]
    return ccs10
    
def icd10toccs(df,col_icd='icd10'):
    ccs10 = load_ccs10()
    output = df.merge(ccs10,how='left',left_on=col_icd,right_on='ICD-10-CM CODE')
    if col_icd!='ICD-10-CM CODE':
        output.drop('ICD-10-CM CODE',axis=1,inplace=True)
    return output

def parsediag(dfin,col_icd,col_id,icd_version):
    df = dfin.copy()
    
    if icd_version==9:
        toccs = icd9toccs
    elif icd_version==10:
        toccs = icd10toccs
    else:
        print('ERROR: Please set icd_version to 9 or 10')
        return None
    
    df = toccs(df,col_icd=col_icd)
    
    if icd_version==9:
        tocci = icd9tocci
    elif icd_version==10:
        tocci = icd10tocci
    
    df = tocci(df,col_icd=col_icd)
    
    df = icdtoelixcomo(df,col_icd=col_icd)
    
    df = df.loc[:,list(dfin.columns)+['CCS CATEGORY','CCS CATEGORY DESCRIPTION','CHRONIC','ElixComo','ElixComoScore']]
    
    
    return df

# onehotifying columns
def onehotify(df,col_id,col_val):
    return pd.concat([df.loc[:,[col_id]],pd.get_dummies(df[col_val])],axis=1).groupby(col_id).max()

def ndc2rxcui(df_med,col_ndc='ndc'):
    print('Converting NDC to RXCUI')
    output=[]
    ndclist=df_med[col_ndc].unique()
    lenndc = len(ndclist)
    for i in range(0,len(ndclist)):
        print('{}/{}, {:.2f}% complete'.format((i+1),lenndc,(i+1)/lenndc*100), end='\r', flush=True)
        curndc=ndclist[i]
        r=requests.get('https://rxnav.nlm.nih.gov/REST/ndcstatus.json?ndc='+str(curndc)).json()['ndcStatus']
        if 'ndcHistory' in r:
            for entry in r['ndcHistory']:
                output.append({
                    'ndc':curndc,
                    'rxcui':entry['activeRxcui'],
                    'start':pd.to_datetime(entry['startDate']+'01'),
                    'end':pd.to_datetime(entry['endDate']+'01'),
                })
        else:
            print('NDC code [{}] was not able to be mapped to rxcui'.format(curndc))
        time.sleep(1/20)
    output=pd.DataFrame(output).replace({r'^\s*$':None}, regex=True).dropna()
    return output
def rxcui2class(df_mapin,getname=True):
    print('Converting rxcui to drug class')
    rxcuilist=df_mapin['rxcui'].unique()
    lenrxcui=len(rxcuilist)
    output=[]
    
    identifier='classId'
    if getname:
        identifier='className'
    
    for i in range(0,lenrxcui):
        print('{}/{}, {:.2f}% complete'.format((i+1),lenrxcui,(i+1)/lenrxcui*100), end='\r', flush=True)
        currxcui=rxcuilist[i]
        r=requests.get('https://rxnav.nlm.nih.gov/REST/rxclass/class/byRxcui.json?rxcui='+str(currxcui)).json()

        if 'rxclassDrugInfoList' in r:
            tempdict={'rxcui':currxcui}
            for curclass in r['rxclassDrugInfoList']['rxclassDrugInfo']:
                classtype=curclass['relaSource']+'_'+curclass['rxclassMinConceptItem']['classType']
                if classtype not in tempdict:
                    tempdict[classtype]=set([curclass['rxclassMinConceptItem'][identifier]])
                else:
                    tempdict[classtype].add(curclass['rxclassMinConceptItem'][identifier])
            output.append(tempdict)
        else:
            print('rxcui [{}] was not able to be mapped to drug class'.format(currxcui))
        time.sleep(1/20)
    return pd.DataFrame(output)
def ndc2class(df_med,col_ndc='ndc',getname=True,indexcol='ROWID',timecol='TIME'):
    map1=ndc2rxcui(df_med,col_ndc=col_ndc)
    map2=rxcui2class(map1,getname=getname)

    newmed=df_med.copy()
    
    #merge maps to go from ndc to rxnorm to class
    fullmap=map1.merge(map2,how='left',on='rxcui')
    
    #merge medication dataframe to full map
    temp=newmed.merge(fullmap,how='left',left_on=col_ndc,right_on='ndc')
    
    #filter based on start and end date
    temp=temp.loc[(temp[timecol]>=temp.start) & (temp[timecol] <=temp.end),:]
    
    #if multiple rxcui per ndc, take the one with the later end date
    temp=temp.sort_values('end')
    temp=temp.drop_duplicates(subset=df_med.columns,keep='last')

    #if no rxcui exist for ndc given the time range, try to just take the latest rxcui
    temp=pd.concat([temp,newmed.loc[~newmed[indexcol].isin(temp[indexcol]),:].merge(fullmap.sort_values(by='end').drop_duplicates(subset='ndc',keep='last'),how='left',left_on='NDC',right_on='ndc')],axis=0)
    temp=temp.sort_values(by=indexcol)
    return temp

# %%
#helper function for loading diagdf

def loaddiagdf():
    diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\mixicdtest.csv').iloc[:,1:]
    diagdf.ICDX_VERSION_NO = diagdf.ICDX_VERSION_NO.str.strip('-CM')
    diagdf.ICDX_DIAGNOSIS_CODE = diagdf.ICDX_DIAGNOSIS_CODE.str.replace('.','')
    diagdf.ICDX_DIAGNOSIS_CODE = diagdf.ICDX_DIAGNOSIS_CODE.str.strip(' ')
    return diagdf

# %%
# ICD 9 to 10

#https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html
def load_icd9to10():
    icd9to10 = pd.read_csv(os.path.join(os.getcwd(),'2018_I9gem.txt'),delim_whitespace=True,header=None,dtype=str)
    icd9to10.columns=['icd9','icd10','flag']
    return icd9to10

#https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html
def load_icd10to9():
    icd10to9 = pd.read_csv(os.path.join(os.getcwd(),'2018_I10gem.txt'),delim_whitespace=True,header=None,dtype=str)
    icd10to9.columns=['icd10','icd9','flag']
    return icd10to9

#https://www.cms.gov/Medicare/Coding/ICD10/2018-ICD-10-CM-and-GEMs.html
def icdconvert(df,col_icd='icd',icd_version=9):
    if icd_version==9:
        source='icd9'
        target='icd10'
        df_gem=load_icd9to10()
    elif icd_version==10:
        source='icd10'
        target='icd9'
        df_gem=load_icd10to9()
    else:
        print('invalid icd version {}, please set curicd to 9 or 10'.format(icd_version))
        return None
    
    print('Comment: because of the discrepancy between icd9 and icd10, diagnosis codes may be mapped to many codes or no codes')
    
    output=df.merge(df_gem,how='left',left_on=col_icd,right_on=source)
    print('{:.2f}% mapped'.format(output[target].notnull().mean()*100))
    if 'flag' in output.columns:
        output.drop('flag',axis=1,inplace=True)
    if col_icd!=source in output.columns:
        output.drop(source,axis=1,inplace=True)
    
    return output


#diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\DIAGNOSES_ICD.csv')
#icdconvert(diagdf,col_icd='ICD9_CODE',col_pid='HADM_ID').head()

diagdf = loaddiagdf()

display(icdconvert(diagdf.loc[diagdf.ICDX_VERSION_NO=='9'],col_icd = 'ICDX_DIAGNOSIS_CODE',icd_version=9).head())
display(icdconvert(diagdf.loc[diagdf.ICDX_VERSION_NO=='10'],col_icd = 'ICDX_DIAGNOSIS_CODE',icd_version=10).head())
# Out:
# Comment: because of the discrepancy between icd9 and icd10, diagnosis codes may be mapped to many codes or no codes
# 97.70% mapped
#   ICDX_VERSION_NO ICDX_DIAGNOSIS_CODE               DESCRIPTION    icd10
# 0               9               36911   1 EYE-SEV/OTH-BLIND NOS    H5410
# 1               9               94810  10-19% BDY BRN/3 DEG NOS    T3110
# 2               9               94810  10-19% BDY BRN/3 DEG NOS    T3210
# 3               9               94214         1ST DEG BURN BACK  T2113XA
# 4               9               94214         1ST DEG BURN BACK  T2153XA
# Comment: because of the discrepancy between icd9 and icd10, diagnosis codes may be mapped to many codes or no codes
# 99.03% mapped
#   ICDX_VERSION_NO ICDX_DIAGNOSIS_CODE  \
# 0              10                G912
# 1              10               Z3A10
# 2              10               Z3A11
# 3              10               Z3A12
# 4              10               Z3A13
#
#                                   DESCRIPTION  icd9
# 0  (Idiopathic) normal pressure hydrocephalus  3315
# 1             10 weeks gestation of pregnancy  NoDx
# 2             11 weeks gestation of pregnancy  NoDx
# 3             12 weeks gestation of pregnancy  NoDx
# 4             13 weeks gestation of pregnancy  NoDx

# %%
# Elixhauser Comorbidities from ICD 9 or 10
def loadelixcomo():
    elixcomo = pd.read_csv('Elixhauser_Comorbidities.csv').iloc[:,1:]
    return elixcomo

def icdtoelixcomo(df,col_icd):
    elixcomo = loadelixcomo()
    unqcomos = elixcomo['Comorbidity'].unique()
    df['ElixComo']=None
    df['ElixComoScore']=None
    for como in unqcomos:
        icdlist = tuple(elixcomo.loc[elixcomo['Comorbidity']==como,'ICD'])
        comoidx = df[col_icd].str.startswith(icdlist,na=False)
        df.loc[comoidx,'ElixComo']=como
        df.loc[comoidx,'ElixComoScore']=elixcomo.loc[elixcomo.Comorbidity==como,'Score'].values[0]
    return df
  

def elixcomoscore(df,col_icd,col_id):
    output = icdtoelixcomo(df,col_icd)
    output = output.loc[output['ElixComo'].notnull(),:]
    output = output.loc[:,[col_id,'ElixComo','ElixComoScore']]
    output = output.drop_duplicates()
    output = pd.DataFrame(output.groupby(col_id)['ElixComoScore'].sum()).reset_index()
    output = output.merge(df.loc[:,[col_id]].drop_duplicates(),how='outer',left_on=col_id,right_on=col_id).fillna(0.)
    return output
    
diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\DIAGNOSES_ICD.csv')
d_diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\D_ICD_DIAGNOSES.csv')
diagdf = diagdf.drop('ROW_ID',axis=1).merge(d_diagdf.drop('ROW_ID',axis=1),how='left',on='ICD9_CODE')

elixcomoscore(diagdf,'ICD9_CODE','HADM_ID').head()
#diagdf = icdtoelixcomo(diagdf,'ICD9_CODE')
#diagdf = diagdf.loc[diagdf.ElixComo.notnull(),:]

#onehotify(diagdf,col_id='HADM_ID',col_val='ElixComo')
#diagdf.loc[:,'ElixComoScore'] = pd.to_numeric(diagdf['ElixComoScore'])
#diagdf.pivot_table(index='HADM_ID',columns='ElixComo',values='ElixComoScore').fillna(0)

#diagdf = loaddiagdf()
#diagdf = diagdf.loc[diagdf['ICDX_VERSION_NO']=='10',:]
#diagdf = icdtoelixcomo(diagdf,col_icd='ICDX_DIAGNOSIS_CODE')
# Out:
#    HADM_ID  ElixComoScore
# 0   100375           12.0
# 1   100969           10.0
# 2   101361           20.0
# 3   102203           22.0
# 4   103379           16.0

# %%
# Chronic Condition Indicator (CCI) from ICD 9

#https://www.hcup-us.ahrq.gov/toolssoftware/chronic/chronic.jsp
def load_cci9():
    cci9 = pd.read_csv(os.path.join(os.getcwd(),'cci2015.csv'),skiprows=1)
    cci9.columns = [i.strip('\'') for i in cci9.columns]
    
    for col in cci9.columns:
        cci9.loc[:,col] = cci9[col].str.strip('\'')
    cci9 = cci9.replace(r'^\s*$', np.nan, regex=True)
    cci9.columns=[i.replace('CATEGORY DESCRIPTION','CHRONIC') for i in cci9.columns]

    dict_bodysystem=[
        ('1' ,'Infectious and parasitic disease'),
        ('2' ,'Neoplasms'),
        ('3' ,'Endocrine, nutritional, and metabolic diseases and immunity disorders'),
        ('4' ,'Diseases of blood and blood-forming organs'),
        ('5' ,'Mental disorders'),
        ('6' ,'Diseases of the nervous system and sense organs'),
        ('7' ,'Diseases of the circulatory system'),
        ('8' ,'Diseases of the respiratory system'),
        ('9' ,'Diseases of the digestive system'),
        ('10','Diseases of the genitourinary system'),
        ('11','Complications of pregnancy, childbirth, and the puerperium'),
        ('12','Diseases of the skin and subcutaneous tissue'),
        ('13','Diseases of the musculoskeletal system'),
        ('14','Congenital anomalies'),
        ('15','Certain conditions originating in the perinatal period'),
        ('16','Symptoms, signs, and ill-defined conditions'),
        ('17','Injury and poisoning'),
        ('18','Factors influencing health status and contact with health service'),
    ]
    
    cci9 = cci9.merge(pd.DataFrame(dict_bodysystem,columns=['BODY SYSTEM','BODY SYSTEM DESCRIPTION']),how='left',on='BODY SYSTEM')
    
    cci9.loc[:,'ICD-9-CM CODE'] = cci9['ICD-9-CM CODE'].str.replace(' ','')
    
    return cci9

def icd9tocci(df,col_icd='icd9'):
    cci9 = load_cci9()
    return df.merge(cci9,how='left',left_on=col_icd,right_on='ICD-9-CM CODE')

diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\DIAGNOSES_ICD.csv')
d_diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\D_ICD_DIAGNOSES.csv')
diagdf = diagdf.drop('ROW_ID',axis=1).merge(d_diagdf.drop('ROW_ID',axis=1),how='left',on='ICD9_CODE')

icdtocci9(diagdf,col_icd='ICD9_CODE').head()
# Out:
#    SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE               SHORT_TITLE  \
# 0       10032   140372        3      5070    Food/vomit pneumonitis
# 1       10032   140372        4     42830  Diastolc hrt failure NOS
# 2       10032   140372        5      4280                   CHF NOS
# 3       10032   140372        6      2851   Ac posthemorrhag anemia
# 4       10032   140372        7      2765                       NaN
#
#                                          LONG_TITLE ICD-9-CM CODE  \
# 0  Pneumonitis due to inhalation of food or vomitus          5070
# 1              Diastolic heart failure, unspecified         42830
# 2             Congestive heart failure, unspecified          4280
# 3                      Acute posthemorrhagic anemia          2851
# 4                                               NaN          2765
#
#                           ICD-9-CM CODE DESCRIPTION CHRONIC BODY SYSTEM  \
# 0                            FOOD/VOMIT PNEUMONITIS       0           8
# 1  UNSPECIFIED DIASTOLIC HEART FAILURE (Begin 2002)       1           7
# 2                          CONGESTIVE HEART FAILURE       1           7
# 3                           AC POSTHEMORRHAG ANEMIA       0           4
# 4                           HYPOVOLEMIA  (End 2005)       0           3
#
#                              BODY SYSTEM DESCRIPTION
# 0                 Diseases of the respiratory system
# 1                 Diseases of the circulatory system
# 2                 Diseases of the circulatory system
# 3         Diseases of blood and blood-forming organs
# 4  Endocrine, nutritional, and metabolic diseases...

# %%
# Chronic Condition Indicator (CCI) from ICD 10

#https://www.hcup-us.ahrq.gov/toolssoftware/chronic_icd10/chronic_icd10.jsp
def load_cci10():
    
    cci10 = pd.read_csv(os.path.join(os.getcwd(),'cci_icd10cm_2019_1.csv'))
    
    cci10.columns = [i.strip('\'') for i in cci10.columns]
    
    for col in cci10.columns:
        cci10.loc[:,col] = cci10[col].str.strip('\'')
    cci10 = cci10.replace(r'^\s*$', np.nan, regex=True)
    cci10.columns = [i.replace('CHRONIC INDICATOR','CHRONIC') for i in cci10.columns]
    
    dict_bodysystem = [
        ('1','Infectious and parasitic disease'),
        ('2','Neoplasms'),
        ('3','Endocrine, nutritional, and metabolic diseases and immunity disorders'),
        ('4','Diseases of blood and blood-forming organs'),
        ('5','Mental disorders'),
        ('6','Diseases of the nervous system and sense organs'),
        ('7','Diseases of the circulatory system'),
        ('8','Diseases of the respiratory system'),
        ('9','Diseases of the digestive system'),
        ('10','Diseases of the genitourinary system'),
        ('11','Complications of pregnancy, childbirth, and the puerperium'),
        ('12','Diseases of the skin and subcutaneous tissue'),
        ('13','Diseases of the musculoskeletal system'),
        ('14','Congenital anomalies'),
        ('15','Certain conditions originating in the perinatal period'),
        ('16','Symptoms, signs, and ill-defined conditions'),
        ('17','Injury and poisoning'),
        ('18','Factors influencing health status and contact with health services'),
    ]
    
    cci10 = cci10.merge(pd.DataFrame(dict_bodysystem,columns=['BODY SYSTEM','BODY SYSTEM DESCRIPTION']),how='left',on='BODY SYSTEM')
    
    cci10.loc[:,'ICD-10-CM CODE'] = cci10['ICD-10-CM CODE'].str.replace(' ','')
    
    return cci10

def icd10tocci(df,col_icd='icd10'):
    cci10 = load_cci10()
    return df.merge(cci10,how='left',left_on=col_icd,right_on='ICD-10-CM CODE')



diagdf=loaddiagdf()
diagdf=diagdf.loc[diagdf['ICDX_VERSION_NO']=='10',:]
#load_cci10()
#diagdf.merge(load_cci10(),how='left',left_on='ICDX_DIAGNOSIS_CODE',right_on='ICD-10-CM CODE').head()
icd10tocci(diagdf,col_icd='ICDX_DIAGNOSIS_CODE').head()
# Out:
#   ICDX_VERSION_NO ICDX_DIAGNOSIS_CODE  \
# 0              10                G912
# 1              10               Z3A10
# 2              10               Z3A11
# 3              10               Z3A12
# 4              10               Z3A13
#
#                                   DESCRIPTION ICD-10-CM CODE  \
# 0  (Idiopathic) normal pressure hydrocephalus           G912
# 1             10 weeks gestation of pregnancy          Z3A10
# 2             11 weeks gestation of pregnancy          Z3A11
# 3             12 weeks gestation of pregnancy          Z3A12
# 4             13 weeks gestation of pregnancy          Z3A13
#
#                    ICD-10-CM CODE DESCRIPTION CHRONIC BODY SYSTEM  \
# 0  (Idiopathic) normal pressure hydrocephalus       1           6
# 1             10 weeks gestation of pregnancy       0          18
# 2             11 weeks gestation of pregnancy       0          18
# 3             12 weeks gestation of pregnancy       0          18
# 4             13 weeks gestation of pregnancy       0          18
#
#                              BODY SYSTEM DESCRIPTION
# 0    Diseases of the nervous system and sense organs
# 1  Factors influencing health status and contact ...
# 2  Factors influencing health status and contact ...
# 3  Factors influencing health status and contact ...
# 4  Factors influencing health status and contact ...

# %%
# Clinical Classification Software (CCS) from ICD 9

#https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp
def load_ccs9():
    ccs9 = pd.read_csv(os.path.join(os.getcwd(),'$dxref 2015.csv'))
    ccs9 = ccs9.reset_index()
    for col in ccs9.columns:
        ccs9.loc[:,col]=ccs9[col].str.strip('\'')
    ccs9.columns=ccs9.iloc[0,:]
    ccs9 = ccs9.iloc[1:,:]
    ccs9 = ccs9.replace(r'^\s*$', np.nan, regex=True)
    ccs9 = ccs9.loc[ccs9['ICD-9-CM CODE'].notnull(),:]
    ccs9.loc[:,'ICD-9-CM CODE'] = ccs9['ICD-9-CM CODE'].str.replace(' ','')
    ccs9.loc[:,'CCS CATEGORY'] = ccs9['CCS CATEGORY'].str.replace(' ','')
    ccs9 = ccs9.iloc[:,0:4]    
    ccs9_labels = pd.read_csv(os.path.join(os.getcwd(),'dxlabel 2015.csv'))
    ccs9 = ccs9.merge(ccs9_labels,how='left',left_on='CCS CATEGORY',right_on='CCS DIAGNOSIS CATEGORIES')
    ccs9.drop('CCS CATEGORY DESCRIPTION',axis=1,inplace=True)
    ccs9.drop('CCS DIAGNOSIS CATEGORIES',axis=1,inplace=True)
    ccs9.columns = [i.replace('CCS DIAGNOSIS CATEGORIES LABELS','CCS CATEGORY DESCRIPTION') for i in ccs9.columns]
    return ccs9

#https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp
def icd9toccs(df,col_icd='icd9'):
    ccs9 = load_ccs9()
    output = df.merge(ccs9,how='left',left_on=col_icd,right_on='ICD-9-CM CODE')
    if col_icd!='ICD-9-CM CODE':
        output.drop('ICD-9-CM CODE',axis=1,inplace=True)
    return output

def onehotify(df,col_id,col_val):
    return pd.concat([df.loc[:,[col_id]],pd.get_dummies(df[col_val])],axis=1).groupby(col_id).max()

diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\DIAGNOSES_ICD.csv')
#onehotify(icd9toccs(diagdf,col_icd='ICD9_CODE'),'HADM_ID','CCS CATEGORY DESCRIPTION').mean().sort_values(ascending=False)
display(icd9toccs(diagdf,col_icd='ICD9_CODE').head())
display(onehotify(icd9toccs(diagdf,col_icd='ICD9_CODE'),col_id='HADM_ID',col_val='CCS CATEGORY DESCRIPTION').head())
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE CCS CATEGORY  \
# 0  112565       10032   140372        3      5070          129
# 1  112566       10032   140372        4     42830          108
# 2  112567       10032   140372        5      4280          108
# 3  112568       10032   140372        6      2851           60
# 4  112569       10032   140372        7      2765           55
#
#                           ICD-9-CM CODE DESCRIPTION  \
# 0                           FOOD/VOMIT PNEUMONITIS-
# 1  UNSPECIFIED DIASTOLIC HEART FAILURE (Begin 2002)
# 2                          CONGESTIVE HEART FAILURE
# 3                          AC POSTHEMORRHAG ANEMIA-
# 4                            HYPOVOLEMIA (End 2005)
#
#                     CCS CATEGORY DESCRIPTION
# 0       Aspiration pneumonitis; food/vomitus
# 1  Congestive heart failure; nonhypertensive
# 2  Congestive heart failure; nonhypertensive
# 3               Acute posthemorrhagic anemia
# 4            Fluid and electrolyte disorders
#          Abdominal hernia  Abdominal pain  \
# HADM_ID
# 100375                  0               0
# 100969                  0               0
# 101361                  0               0
# 102203                  0               0
# 103379                  0               0
#
#          Acute and unspecified renal failure  Acute cerebrovascular disease  \
# HADM_ID
# 100375                                     1                              0
# 100969                                     0                              1
# 101361                                     1                              0
# 102203                                     1                              0
# 103379                                     0                              0
#
#          Acute myocardial infarction  Acute posthemorrhagic anemia  \
# HADM_ID
# 100375                             0                             0
# 100969                             0                             0
# 101361                             0                             0
# 102203                             0                             0
# 103379                             0                             0
#
#          Administrative/social admission  Alcohol-related disorders  \
# HADM_ID
# 100375                                 0                          0
# 100969                                 0                          0
# 101361                                 0                          1
# 102203                                 0                          1
# 103379                                 0                          0
#
#          Allergic reactions  Anal and rectal conditions  \
# HADM_ID
# 100375                    0                           0
# 100969                    0                           0
# 101361                    0                           0
# 102203                    0                           0
# 103379                    0                           0
#
#                        ...                  Skull and face fractures  \
# HADM_ID                ...
# 100375                 ...                                         0
# 100969                 ...                                         0
# 101361                 ...                                         0
# 102203                 ...                                         0
# 103379                 ...                                         0
#
#          Spinal cord injury  \
# HADM_ID
# 100375                    0
# 100969                    0
# 101361                    0
# 102203                    0
# 103379                    0
#
#          Spondylosis; intervertebral disc disorders; other back problems  \
# HADM_ID
# 100375                                                   0
# 100969                                                   0
# 101361                                                   0
# 102203                                                   0
# 103379                                                   0
#
#          Substance-related disorders  \
# HADM_ID
# 100375                             0
# 100969                             0
# 101361                             0
# 102203                             0
# 103379                             0
#
#          Suicide and intentional self-inflicted injury  Syncope  \
# HADM_ID
# 100375                                               0        0
# 100969                                               0        0
# 101361                                               0        0
# 102203                                               0        0
# 103379                                               0        0
#
#          Thyroid disorders  Tuberculosis  Urinary tract infections  \
# HADM_ID
# 100375                   0             0                         1
# 100969                   0             0                         0
# 101361                   0             0                         0
# 102203                   0             0                         0
# 103379                   1             0                         0
#
#          Varicose veins of lower extremity
# HADM_ID
# 100375                                   0
# 100969                                   0
# 101361                                   0
# 102203                                   0
# 103379                                   0
#
# [5 rows x 168 columns]

# %%
# Clinical Classification Software (CCS) from ICD 10

#https://www.hcup-us.ahrq.gov/toolssoftware/ccs10/ccs10.jsp


def load_ccs10():
    ccs10 = pd.read_csv(os.path.join(os.getcwd(),'ccs_dx_icd10cm_2019_1.csv'))
    ccs10.columns=[i.strip('\'') for i in ccs10.columns]
    for col in ccs10.columns:
        ccs10.loc[:,col]=ccs10[col].str.strip('\'')
    ccs10 = ccs10.replace(r'^\s*$', np.nan, regex=True)
    ccs10.loc[:,'ICD-10-CM CODE'] = ccs10['ICD-10-CM CODE'].str.replace(' ','')
    ccs10=ccs10.iloc[:,0:4]
    return ccs10
    
def icd10toccs(df,col_icd='icd10'):
    ccs10 = load_ccs10()
    output = df.merge(ccs10,how='left',left_on=col_icd,right_on='ICD-10-CM CODE')
    if col_icd!='ICD-10-CM CODE':
        output.drop('ICD-10-CM CODE',axis=1,inplace=True)
    return output

    

diagdf =loaddiagdf()
diagdf=diagdf.loc[diagdf['ICDX_VERSION_NO']=='10',:]
display(icd10toccs(diagdf,col_icd='ICDX_DIAGNOSIS_CODE').head())
# Out:
#   ICDX_VERSION_NO ICDX_DIAGNOSIS_CODE  \
# 0              10                G912
# 1              10               Z3A10
# 2              10               Z3A11
# 3              10               Z3A12
# 4              10               Z3A13
#
#                                   DESCRIPTION CCS CATEGORY  \
# 0  (Idiopathic) normal pressure hydrocephalus           95
# 1             10 weeks gestation of pregnancy          259
# 2             11 weeks gestation of pregnancy          259
# 3             12 weeks gestation of pregnancy          259
# 4             13 weeks gestation of pregnancy          259
#
#                    ICD-10-CM CODE DESCRIPTION        CCS CATEGORY DESCRIPTION
# 0  (Idiopathic) normal pressure hydrocephalus  Other nervous system disorders
# 1             10 weeks gestation of pregnancy    Residual codes; unclassified
# 2             11 weeks gestation of pregnancy    Residual codes; unclassified
# 3             12 weeks gestation of pregnancy    Residual codes; unclassified
# 4             13 weeks gestation of pregnancy    Residual codes; unclassified

# %%
diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\DIAGNOSES_ICD.csv')
d_diagdf = pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\D_ICD_DIAGNOSES.csv')
diagdf = diagdf.drop('ROW_ID',axis=1).merge(d_diagdf.drop('ROW_ID',axis=1),how='left',on='ICD9_CODE')

# Everything together

def parsediag(dfin,col_icd,col_id,icd_version):
    df = dfin.copy()
    
    if icd_version==9:
        toccs = icd9toccs
    elif icd_version==10:
        toccs = icd10toccs
    else:
        print('ERROR: Please set icd_version to 9 or 10')
        return None
    
    df = toccs(df,col_icd=col_icd)
    
    if icd_version==9:
        tocci = icd9tocci
    elif icd_version==10:
        tocci = icd10tocci
    
    df = tocci(df,col_icd=col_icd)
    
    df = icdtoelixcomo(df,col_icd=col_icd)
    
    df = df.loc[:,list(dfin.columns)+['CCS CATEGORY','CCS CATEGORY DESCRIPTION','CHRONIC','ElixComo','ElixComoScore']]
    
    
    return df

parsediag(diagdf,col_icd='ICD9_CODE',col_id='HADM_ID',icd_version=9)
# Out:
#       SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE               SHORT_TITLE  \
# 0          10032   140372        3      5070    Food/vomit pneumonitis
# 1          10032   140372        4     42830  Diastolc hrt failure NOS
# 2          10032   140372        5      4280                   CHF NOS
# 3          10032   140372        6      2851   Ac posthemorrhag anemia
# 4          10032   140372        7      2765                       NaN
# 5          10032   140372        8      2875      Thrombocytopenia NOS
# 6          10032   140372        9      5849  Acute kidney failure NOS
# 7          10033   157235        1     24220  Tox multnod goit no cris
# 8          10033   157235        2     51919  Trachea & bronch dis NEC
# 9          10033   157235        3      5849  Acute kidney failure NOS
# 10         10033   157235        4      2767           Hyperpotassemia
# 11         10033   157235        5     42731       Atrial fibrillation
# 12         10033   157235        6     E8889                  Fall NOS
# 13         10033   157235        7      4019          Hypertension NOS
# 14         10033   157235        8     25000  DMII wo cmp nt st uncntr
# 15         10033   157235        9      2720   Pure hypercholesterolem
# 16         10033   157235       10       311   Depressive disorder NEC
# 17         10033   157235       11     43811   Late eff CV dis-aphasia
# 18         10033   157235       12     53390          Peptic ulcer NOS
# 19         10035   110244        1     43310    Ocl crtd art wo infrct
# 20         10035   110244        2      2749                  Gout NOS
# 21         10035   110244        3      6000                       NaN
# 22         10035   110244        4       412    Old myocardial infarct
# 23         10036   189483        1      0389            Septicemia NOS
# 24         10036   189483        2     78552              Septic shock
# 25         10036   189483        3      5070    Food/vomit pneumonitis
# 26         10036   189483        4      5849  Acute kidney failure NOS
# 27         10036   189483        5      2762                  Acidosis
# 28         10036   189483        6      2765                       NaN
# 29         10036   189483        7      2554                       NaN
# ...          ...      ...      ...       ...                       ...
# 1731       43881   167021       14     V5861  Long-term use anticoagul
# 1732       43881   167021       15     56400          Constipation NOS
# 1733       43881   167021       16      2800     Chr blood loss anemia
# 1734       43881   167021       17      2724    Hyperlipidemia NEC/NOS
# 1735       43881   172454        1     41519    Pulm embol/infarct NEC
# 1736       43881   172454        2       486   Pneumonia, organism NOS
# 1737       43881   172454        3      5789   Gastrointest hemorr NOS
# 1738       43881   172454        4      1508     Mal neo esophagus NEC
# 1739       43881   172454        5      1977    Second malig neo liver
# 1740       43881   172454        6      1970  Secondary malig neo lung
# 1741       43881   172454        7      1985  Secondary malig neo bone
# 1742       43881   172454        8      2761             Hyposmolality
# 1743       43881   172454        9     45340   Ac DVT/embl low ext NOS
# 1744       43881   172454       10     40391    Hyp kid NOS w cr kid V
# 1745       43881   172454       11      5856   End stage renal disease
# 1746       43881   172454       12      V420  Kidney transplant status
# 1747       43881   172454       13      2724    Hyperlipidemia NEC/NOS
# 1748       43881   172454       14      2749                  Gout NOS
# 1749       43881   172454       15     71940         Joint pain-unspec
# 1750       43881   172454       16     53190         Stomach ulcer NOS
# 1751       43881   172454       17     32723   Obstructive sleep apnea
# 1752       43909   167612        1       486   Pneumonia, organism NOS
# 1753       43909   167612        2      1983   Sec mal neo brain/spine
# 1754       43909   167612        3      1628   Mal neo bronch/lung NEC
# 1755       43909   167612        4      2536   Neurohypophysis dis NEC
# 1756       43909   167612        5       496   Chr airway obstruct NEC
# 1757       43909   167612        6     42731       Atrial fibrillation
# 1758       43909   167612        7       311   Depressive disorder NEC
# 1759       43909   167612        8      4589           Hypotension NOS
# 1760       43909   167612        9      7991        Respiratory arrest
#
#                                              LONG_TITLE CCS CATEGORY  \
# 0      Pneumonitis due to inhalation of food or vomitus          129
# 1                  Diastolic heart failure, unspecified          108
# 2                 Congestive heart failure, unspecified          108
# 3                          Acute posthemorrhagic anemia           60
# 4                                                   NaN           55
# 5                         Thrombocytopenia, unspecified           62
# 6                     Acute kidney failure, unspecified          157
# 7     Toxic multinodular goiter without mention of t...           48
# 8                Other diseases of trachea and bronchus          134
# 9                     Acute kidney failure, unspecified          157
# 10                                      Hyperpotassemia           55
# 11                                  Atrial fibrillation          106
# 12                                     Unspecified fall         2603
# 13                   Unspecified essential hypertension           98
# 14    Diabetes mellitus without mention of complicat...           49
# 15                            Pure hypercholesterolemia           53
# 16        Depressive disorder, not elsewhere classified          657
# 17     Late effects of cerebrovascular disease, aphasia          113
# 18    Peptic ulcer of unspecified site, unspecified ...          139
# 19    Occlusion and stenosis of carotid artery witho...          110
# 20                                    Gout, unspecified           54
# 21                                                  NaN          164
# 22                            Old myocardial infarction          101
# 23                               Unspecified septicemia            2
# 24                                         Septic shock          249
# 25     Pneumonitis due to inhalation of food or vomitus          129
# 26                    Acute kidney failure, unspecified          157
# 27                                             Acidosis           55
# 28                                                  NaN           55
# 29                                                  NaN           51
# ...                                                 ...          ...
# 1731          Long-term (current) use of anticoagulants          257
# 1732                          Constipation, unspecified          155
# 1733  Iron deficiency anemia secondary to blood loss...           59
# 1734               Other and unspecified hyperlipidemia           53
# 1735            Other pulmonary embolism and infarction          103
# 1736                    Pneumonia, organism unspecified          122
# 1737  Hemorrhage of gastrointestinal tract, unspecified          153
# 1738  Malignant neoplasm of other specified part of ...           12
# 1739             Malignant neoplasm of liver, secondary           42
# 1740               Secondary malignant neoplasm of lung           42
# 1741  Secondary malignant neoplasm of bone and bone ...           42
# 1742                  Hyposmolality and/or hyponatremia           55
# 1743  Acute venous embolism and thrombosis of unspec...          118
# 1744  Hypertensive chronic kidney disease, unspecifi...           99
# 1745                            End stage renal disease          158
# 1746                      Kidney replaced by transplant          158
# 1747               Other and unspecified hyperlipidemia           53
# 1748                                  Gout, unspecified           54
# 1749                    Pain in joint, site unspecified          204
# 1750  Gastric ulcer, unspecified as acute or chronic...          139
# 1751         Obstructive sleep apnea (adult)(pediatric)          259
# 1752                    Pneumonia, organism unspecified          122
# 1753  Secondary malignant neoplasm of brain and spin...           42
# 1754  Malignant neoplasm of other parts of bronchus ...           19
# 1755                 Other disorders of neurohypophysis           51
# 1756  Chronic airway obstruction, not elsewhere clas...          127
# 1757                                Atrial fibrillation          106
# 1758      Depressive disorder, not elsewhere classified          657
# 1759                           Hypotension, unspecified          117
# 1760                                 Respiratory arrest          131
#
#                                CCS CATEGORY DESCRIPTION CHRONIC  \
# 0                  Aspiration pneumonitis; food/vomitus       0
# 1             Congestive heart failure; nonhypertensive       1
# 2             Congestive heart failure; nonhypertensive       1
# 3                          Acute posthemorrhagic anemia       0
# 4                       Fluid and electrolyte disorders       0
# 5                 Coagulation and hemorrhagic disorders       1
# 6                   Acute and unspecified renal failure       0
# 7                                     Thyroid disorders       1
# 8                       Other upper respiratory disease       0
# 9                   Acute and unspecified renal failure       0
# 10                      Fluid and electrolyte disorders       0
# 11                                 Cardiac dysrhythmias       1
# 12                                        E Codes: Fall     NaN
# 13                               Essential hypertension       1
# 14               Diabetes mellitus without complication       1
# 15                        Disorders of lipid metabolism       1
# 16                                       Mood disorders       1
# 17              Late effects of cerebrovascular disease       1
# 18             Gastroduodenal ulcer (except hemorrhage)       1
# 19        Occlusion or stenosis of precerebral arteries       1
# 20                 Gout and other crystal arthropathies       1
# 21                              Hyperplasia of prostate       1
# 22     Coronary atherosclerosis and other heart disease       1
# 23                         Septicemia (except in labor)       0
# 24                                                Shock       0
# 25                 Aspiration pneumonitis; food/vomitus       0
# 26                  Acute and unspecified renal failure       0
# 27                      Fluid and electrolyte disorders       0
# 28                      Fluid and electrolyte disorders       0
# 29                            Other endocrine disorders       1
# ...                                                 ...     ...
# 1731                                    Other aftercare       0
# 1732                   Other gastrointestinal disorders       0
# 1733                        Deficiency and other anemia       1
# 1734                      Disorders of lipid metabolism       1
# 1735                            Pulmonary heart disease       0
# 1736  Pneumonia (except that caused by tuberculosis ...       0
# 1737                        Gastrointestinal hemorrhage       0
# 1738                                Cancer of esophagus       1
# 1739                             Secondary malignancies       1
# 1740                             Secondary malignancies       1
# 1741                             Secondary malignancies       1
# 1742                    Fluid and electrolyte disorders       0
# 1743    Phlebitis; thrombophlebitis and thromboembolism       0
# 1744  Hypertension with complications and secondary ...       1
# 1745                             Chronic kidney disease       1
# 1746                             Chronic kidney disease       1
# 1747                      Disorders of lipid metabolism       1
# 1748               Gout and other crystal arthropathies       1
# 1749                Other non-traumatic joint disorders       0
# 1750           Gastroduodenal ulcer (except hemorrhage)       1
# 1751                       Residual codes; unclassified       1
# 1752  Pneumonia (except that caused by tuberculosis ...       0
# 1753                             Secondary malignancies       1
# 1754                           Cancer of bronchus; lung       1
# 1755                          Other endocrine disorders       1
# 1756  Chronic obstructive pulmonary disease and bron...       1
# 1757                               Cardiac dysrhythmias       1
# 1758                                     Mood disorders       1
# 1759                          Other circulatory disease       0
# 1760  Respiratory failure; insufficiency; arrest (ad...       0
#
#                                      ElixComo ElixComoScore
# 0                                        None          None
# 1                    Congestive Heart Failure             7
# 2                    Congestive Heart Failure             7
# 3                                        None          None
# 4             Fluid and Electrolyte Disorders             5
# 5                                Coagulopathy             3
# 6                                        None          None
# 7                                        None          None
# 8                                        None          None
# 9                                        None          None
# 10            Fluid and Electrolyte Disorders             5
# 11                        Cardiac Arrhythmias             5
# 12                                       None          None
# 13                Hypertension, Uncomplicated             0
# 14                    Diabetes, Uncomplicated             0
# 15                                       None          None
# 16                                 Depression            -3
# 17                                       None          None
# 18    Peptic Ulcer Disease Excluding Bleeding             0
# 19                                       None          None
# 20                                       None          None
# 21                                       None          None
# 22                                       None          None
# 23                                       None          None
# 24                                       None          None
# 25                                       None          None
# 26                                       None          None
# 27            Fluid and Electrolyte Disorders             5
# 28            Fluid and Electrolyte Disorders             5
# 29                                       None          None
# ...                                       ...           ...
# 1731                                     None          None
# 1732                                     None          None
# 1733                        Blood Loss Anemia            -2
# 1734                                     None          None
# 1735          Pulmonary Circulation Disorders             4
# 1736                                     None          None
# 1737                                     None          None
# 1738           Solid Tumor Without Metastasis             4
# 1739                        Metastatic Cancer            12
# 1740                        Metastatic Cancer            12
# 1741                        Metastatic Cancer            12
# 1742          Fluid and Electrolyte Disorders             5
# 1743                                     None          None
# 1744                            Renal Failure             5
# 1745                            Renal Failure             5
# 1746                            Renal Failure             5
# 1747                                     None          None
# 1748                                     None          None
# 1749                                     None          None
# 1750  Peptic Ulcer Disease Excluding Bleeding             0
# 1751                                     None          None
# 1752                                     None          None
# 1753                        Metastatic Cancer            12
# 1754           Solid Tumor Without Metastasis             4
# 1755          Fluid and Electrolyte Disorders             5
# 1756                Chronic Pulmonary Disease             3
# 1757                      Cardiac Arrhythmias             5
# 1758                               Depression            -3
# 1759                                     None          None
# 1760                                     None          None
#
# [1761 rows x 11 columns]

# %%
# NDC to RXNORM to DRUG CLASS

def ndc2rxcui(df_med,col_ndc='ndc'):
    print('Converting NDC to RXCUI')
    output=[]
    ndclist=df_med[col_ndc].unique()
    lenndc = len(ndclist)
    for i in range(0,len(ndclist)):
        print('{}/{}, {:.2f}% complete'.format((i+1),lenndc,(i+1)/lenndc*100), end='\r', flush=True)
        curndc=ndclist[i]
        r=requests.get('https://rxnav.nlm.nih.gov/REST/ndcstatus.json?ndc='+str(curndc)).json()['ndcStatus']
        if 'ndcHistory' in r:
            for entry in r['ndcHistory']:
                output.append({
                    'ndc':curndc,
                    'rxcui':entry['activeRxcui'],
                    'start':pd.to_datetime(entry['startDate']+'01'),
                    'end':pd.to_datetime(entry['endDate']+'01'),
                })
        else:
            print('NDC code [{}] was not able to be mapped to rxcui'.format(curndc))
        time.sleep(1/20)
    output=pd.DataFrame(output).replace({r'^\s*$':None}, regex=True).dropna()
    return output
def rxcui2class(df_mapin,getname=True):
    print('Converting rxcui to drug class')
    rxcuilist=df_mapin['rxcui'].unique()
    lenrxcui=len(rxcuilist)
    output=[]
    
    identifier='classId'
    if getname:
        identifier='className'
    
    for i in range(0,lenrxcui):
        print('{}/{}, {:.2f}% complete'.format((i+1),lenrxcui,(i+1)/lenrxcui*100), end='\r', flush=True)
        currxcui=rxcuilist[i]
        r=requests.get('https://rxnav.nlm.nih.gov/REST/rxclass/class/byRxcui.json?rxcui='+str(currxcui)).json()

        if 'rxclassDrugInfoList' in r:
            tempdict={'rxcui':currxcui}
            for curclass in r['rxclassDrugInfoList']['rxclassDrugInfo']:
                classtype=curclass['relaSource']+'_'+curclass['rxclassMinConceptItem']['classType']
                if classtype not in tempdict:
                    tempdict[classtype]=set([curclass['rxclassMinConceptItem'][identifier]])
                else:
                    tempdict[classtype].add(curclass['rxclassMinConceptItem'][identifier])
            output.append(tempdict)
        else:
            print('rxcui [{}] was not able to be mapped to drug class'.format(currxcui))
        time.sleep(1/20)
    return pd.DataFrame(output)
def ndc2class(df_med,col_ndc='ndc',getname=True,indexcol='ROWID',timecol='TIME'):
    map1=ndc2rxcui(df_med,col_ndc=col_ndc)
    map2=rxcui2class(map1,getname=getname)

    newmed=df_med.copy()
    
    #merge maps to go from ndc to rxnorm to class
    fullmap=map1.merge(map2,how='left',on='rxcui')
    
    #merge medication dataframe to full map
    temp=newmed.merge(fullmap,how='left',left_on=col_ndc,right_on='ndc')
    
    #filter based on start and end date
    temp=temp.loc[(temp[timecol]>=temp.start) & (temp[timecol] <=temp.end),:]
    
    #if multiple rxcui per ndc, take the one with the later end date
    temp=temp.sort_values('end')
    temp=temp.drop_duplicates(subset=df_med.columns,keep='last')

    #if no rxcui exist for ndc given the time range, try to just take the latest rxcui
    temp=pd.concat([temp,newmed.loc[~newmed[indexcol].isin(temp[indexcol]),:].merge(fullmap.sort_values(by='end').drop_duplicates(subset='ndc',keep='last'),how='left',left_on='NDC',right_on='ndc')],axis=0)
    temp=temp.sort_values(by=indexcol)
    return temp


meddf=pd.read_csv(r'C:\Users\Sean Yu\Documents\WUSTL\i2bmi\TESTING\lstm\mimictest\PRESCRIPTIONS.csv',dtype=object)
meddf=meddf.loc[(meddf.NDC.notnull()) & (meddf.DRUG_TYPE=='MAIN') & (meddf.NDC!='0'),:]
meddf.STARTDATE = pd.to_datetime(meddf.STARTDATE)
meddf.ENDDATE = pd.to_datetime(meddf.ENDDATE)
meddf=meddf.loc[:,['ROW_ID','SUBJECT_ID','HADM_ID','STARTDATE','ENDDATE','DRUG','NDC']]
#assigning arbitary time
meddf['TIME']=pd.to_datetime('2011-01-01')

output=ndc2class(meddf,col_ndc='NDC',indexcol='ROW_ID',timecol='TIME')
# Out:
# Converting NDC to RXCUI
# NDC code [15127020017] was not able to be mapped to rxcui
# NDC code [17314931102] was not able to be mapped to rxcui
# NDC code [66591018442] was not able to be mapped to rxcui
# NDC code [17191003500] was not able to be mapped to rxcui
# NDC code [00338101102] was not able to be mapped to rxcui
# NDC code [50383068304] was not able to be mapped to rxcui
# NDC code [00338040360] was not able to be mapped to rxcui
# NDC code [00245008201] was not able to be mapped to rxcui
# NDC code [37205014472] was not able to be mapped to rxcui
# NDC code [55499120401] was not able to be mapped to rxcui
# NDC code [49452477503] was not able to be mapped to rxcui
# NDC code [11980002515] was not able to be mapped to rxcui
# NDC code [00074729501] was not able to be mapped to rxcui
# NDC code [16837085839] was not able to be mapped to rxcui
# NDC code [62174057751] was not able to be mapped to rxcui
# NDC code [66689036430] was not able to be mapped to rxcui
# NDC code [00065041435] was not able to be mapped to rxcui
# NDC code [62584078833] was not able to be mapped to rxcui
# NDC code [00245009101] was not able to be mapped to rxcui
# NDC code [60258000601] was not able to be mapped to rxcui
# NDC code [00904053061] was not able to be mapped to rxcui
# NDC code [00904504260] was not able to be mapped to rxcui
# NDC code [24477001015] was not able to be mapped to rxcui
# NDC code [08489800001] was not able to be mapped to rxcui
# NDC code [87701071218] was not able to be mapped to rxcui
# NDC code [00132000119] was not able to be mapped to rxcui
# Converting rxcui to drug class
# 1087/1087, 100.00% complete

# %%
output
# Out:
#         ROW_ID SUBJECT_ID HADM_ID  STARTDATE    ENDDATE  \
# 945    1093789      43748  121860 2179-04-17 2179-04-23
# 946    1093790      43748  121860 2179-04-17 2179-04-23
# 944    1093791      43748  121860 2179-04-17 2179-04-19
# 18260  1093792      43748  121860 2179-04-17 2179-04-23
# 18252  1093793      43748  121860 2179-04-17 2179-04-17
# 18262  1093794      43748  121860 2179-04-17 2179-04-23
# 18259  1093795      43748  121860 2179-04-17 2179-04-21
# 18266  1093796      43748  121860 2179-04-17 2179-04-23
# 18267  1093797      43748  121860 2179-04-17 2179-04-23
# 18254  1094506      43748  121860 2179-04-17 2179-04-18
# 18283  1094507      43748  121860 2179-04-18 2179-04-19
# 16710  1094509      43748  121860 2179-04-19 2179-04-21
# 16708  1094510      43748  121860 2179-04-19 2179-04-21
# 18299  1094511      43748  121860 2179-04-19 2179-04-20
# 18297  1094512      43748  121860 2179-04-19 2179-04-20
# 16836  1094513      43748  121860 2179-04-19 2179-04-23
# 18301  1094514      43748  121860 2179-04-19 2179-04-20
# 16844  1094515      43748  121860 2179-04-20 2179-04-23
# 16843  1094517      43748  121860 2179-04-20 2179-04-21
# 16852  1094518      43748  121860 2179-04-21 2179-04-21
# 883    1094519      43748  121860 2179-04-21 2179-04-21
# 16859  1094520      43748  121860 2179-04-21 2179-04-23
# 16857  1094521      43748  121860 2179-04-21 2179-04-23
# 16860  1094522      43748  121860 2179-04-21 2179-04-23
# 16862  1094524      43748  121860 2179-04-23 2179-04-23
# 16863  1094525      43748  121860 2179-04-23 2179-04-23
# 16868  1094526      43748  121860 2179-04-23 2179-04-23
# 18250  1094544      43748  121860 2179-04-17 2179-04-17
# 18271  1094545      43748  121860 2179-04-18 2179-04-18
# 18277  1094546      43748  121860 2179-04-18 2179-04-19
# ...        ...        ...     ...        ...        ...
# 10996   950737      40456  161765 2118-10-08 2118-10-09
# 10994   950738      40456  161765 2118-10-08 2118-10-08
# 615     950739      40456  161765 2118-10-08 2118-10-08
# 9487    950740      40456  161765 2118-10-08 2118-10-08
# 9485    950741      40456  161765 2118-10-08 2118-10-08
# 606     976449      10033  157235 2132-12-05 2132-12-05
# 604     976450      10033  157235 2132-12-05 2132-12-05
# 602     976451      10033  157235 2132-12-05 2132-12-05
# 608     976452      10033  157235 2132-12-05 2132-12-05
# 642     977173      10033  157235 2132-12-05 2132-12-08
# 633     977174      10033  157235 2132-12-05 2132-12-08
# 640     977176      10033  157235 2132-12-05 2132-12-08
# 635     977177      10033  157235 2132-12-05 2132-12-08
# 931     977178      10033  157235 2132-12-06 2132-12-08
# 616     977179      10033  157235 2132-12-05 2132-12-08
# 631     977180      10033  157235 2132-12-05 2132-12-08
# 614     977181      10033  157235 2132-12-05 2132-12-08
# 47      977182      10033  157235 2132-12-05 2132-12-08
# 617     977183      10033  157235 2132-12-05 2132-12-08
# 620     977184      10033  157235 2132-12-05 2132-12-08
# 621     977185      10033  157235 2132-12-05 2132-12-08
# 624     977186      10033  157235 2132-12-05 2132-12-08
# 609     977187      10033  157235 2132-12-05 2132-12-05
# 612     977188      10033  157235 2132-12-05 2132-12-06
# 636     977189      10033  157235 2132-12-05 2132-12-08
# 927     977190      10033  157235 2132-12-06 2132-12-08
# 926     977191      10033  157235 2132-12-06 2132-12-08
# 643     977193      10033  157235 2132-12-06 2132-12-08
# 930     977194      10033  157235 2132-12-06 2132-12-08
# 48      977199      10033  157235 2132-12-05 2132-12-08
#
#                                      DRUG          NDC       TIME        end  \
# 945               Influenza Virus Vaccine  58160087546 2011-01-01        NaT
# 946                                 Senna  00904516561 2011-01-01 2018-11-01
# 944              Docusate Sodium (Liquid)  00121054410 2011-01-01 2018-11-01
# 18260                         Simvastatin  51079045620 2011-01-01 2018-11-01
# 18252                   Zolpidem Tartrate  60505260400 2011-01-01 2018-11-01
# 18262                          FoLIC Acid  00182050789 2011-01-01 2013-09-01
# 18259                       Acetaminophen  00182844789 2011-01-01 2013-01-01
# 18266                          Amiodarone  51079090620 2011-01-01 2018-11-01
# 18267                        Pantoprazole  00008084199 2011-01-01 2018-11-01
# 18254                   Zolpidem Tartrate  60505260400 2011-01-01 2018-11-01
# 18283                        Phytonadione  25010040515 2011-01-01 2016-06-01
# 16710                          Oxybutynin  00904282161 2011-01-01 2018-11-01
# 16708                          Cephalexin  51079060520 2011-01-01 2013-09-01
# 18299                   TraMADOL (Ultram)  00406717162 2011-01-01 2013-06-01
# 18297                     Phenazopyridine  00904792260 2011-01-01 2011-03-01
# 16836            Docusate Sodium (Liquid)  00904224461 2011-01-01 2011-09-01
# 18301                   Zolpidem Tartrate  60505260400 2011-01-01 2018-11-01
# 16844                             Aspirin  00904404073 2011-01-01 2018-11-01
# 16843                           traZODONE  00904399061 2011-01-01 2018-11-01
# 16852                  Potassium Chloride  58177020211 2011-01-01 2012-12-01
# 883                    Potassium Chloride  00456066270 2011-01-01        NaT
# 16859  Olanzapine (Disintegrating Tablet)  00002445385 2011-01-01 2018-11-01
# 16857                       Acetaminophen  00182845389 2011-01-01 2018-11-01
# 16860                          Cephalexin  51079060520 2011-01-01 2013-09-01
# 16862                           Torsemide  00004026449 2011-01-01 2018-11-01
# 16863                  Potassium Chloride  58177000111 2011-01-01 2018-11-01
# 16868                          Carvedilol  51079077120 2011-01-01 2018-11-01
# 18250                 Pantoprazole Sodium  00008092355 2011-01-01 2018-11-01
# 18271                       Phenylephrine  10019016312 2011-01-01 2011-12-01
# 18277                           Milrinone  00338601048 2011-01-01 2016-05-01
# ...                                   ...          ...        ...        ...
# 10996                           Captopril  00904504561 2011-01-01 2018-11-01
# 10994                  Potassium Chloride  58177020211 2011-01-01 2012-12-01
# 615                    Potassium Chloride  00456066270 2011-01-01        NaT
# 9487                           Furosemide  00517570425 2011-01-01 2015-11-01
# 9485                   Potassium Chloride  58177020211 2011-01-01 2012-12-01
# 606          Sodium Polystyrene Sulfonate  46287000660 2011-01-01 2016-07-01
# 604                            Metoprolol  51079025520 2011-01-01 2018-11-01
# 602                            Ranitidine  00904526161 2011-01-01 2012-12-01
# 608                          Atorvastatin  00071015540 2011-01-01 2018-11-01
# 642                            Metoprolol  55390007310 2011-01-01 2018-11-01
# 633                               Heparin  00641040025 2011-01-01 2012-12-01
# 640                        Venlafaxine XR  00008083303 2011-01-01 2018-11-01
# 635                            Lisinopril  00172375910 2011-01-01 2018-02-01
# 931                            Furosemide  00054829725 2011-01-01 2018-11-01
# 616                           Methimazole  60793010401 2011-01-01 2018-11-01
# 631                             Donepezil  62856024541 2011-01-01 2018-11-01
# 614                       Docusate Sodium  63739008901 2011-01-01 2011-09-01
# 47                        Docusate Sodium  00121054410 2011-01-01 2018-11-01
# 617         Oxycodone (Sustained Release)  59011010010 2011-01-01 2013-06-01
# 620                         Acetaminophen  00182844789 2011-01-01 2013-01-01
# 621                           Mirtazapine  00052010730 2011-01-01 2018-11-01
# 624                          Atorvastatin  00071015640 2011-01-01 2018-11-01
# 609                   Quetiapine Fumarate  00310027539 2011-01-01 2018-11-01
# 612                           Methimazole  60793010401 2011-01-01 2018-11-01
# 636                   Quetiapine Fumarate  00310027239 2011-01-01 2018-11-01
# 927                   Quetiapine Fumarate  00310027539 2011-01-01 2018-11-01
# 926                           Methimazole  60793010401 2011-01-01 2018-11-01
# 643                          Pantoprazole  00008084199 2011-01-01 2018-11-01
# 930                            Metoprolol  51079025520 2011-01-01 2018-11-01
# 48                             Famotidine  00006353750 2011-01-01 2009-01-01
#
#                ndc                        ...                          \
# 945            NaN                        ...
# 946    00904516561                        ...
# 944    00121054410                        ...
# 18260  51079045620                        ...
# 18252  60505260400                        ...
# 18262  00182050789                        ...
# 18259  00182844789                        ...
# 18266  51079090620                        ...
# 18267  00008084199                        ...
# 18254  60505260400                        ...
# 18283  25010040515                        ...
# 16710  00904282161                        ...
# 16708  51079060520                        ...
# 18299  00406717162                        ...
# 18297  00904792260                        ...
# 16836  00904224461                        ...
# 18301  60505260400                        ...
# 16844  00904404073                        ...
# 16843  00904399061                        ...
# 16852  58177020211                        ...
# 883            NaN                        ...
# 16859  00002445385                        ...
# 16857  00182845389                        ...
# 16860  51079060520                        ...
# 16862  00004026449                        ...
# 16863  58177000111                        ...
# 16868  51079077120                        ...
# 18250  00008092355                        ...
# 18271  10019016312                        ...
# 18277  00338601048                        ...
# ...            ...                        ...
# 10996  00904504561                        ...
# 10994  58177020211                        ...
# 615            NaN                        ...
# 9487   00517570425                        ...
# 9485   58177020211                        ...
# 606    46287000660                        ...
# 604    51079025520                        ...
# 602    00904526161                        ...
# 608    00071015540                        ...
# 642    55390007310                        ...
# 633    00641040025                        ...
# 640    00008083303                        ...
# 635    00172375910                        ...
# 931    00054829725                        ...
# 616    60793010401                        ...
# 631    62856024541                        ...
# 614    63739008901                        ...
# 47     00121054410                        ...
# 617    59011010010                        ...
# 620    00182844789                        ...
# 621    00052010730                        ...
# 624    00071015640                        ...
# 609    00310027539                        ...
# 612    60793010401                        ...
# 636    00310027239                        ...
# 927    00310027539                        ...
# 926    60793010401                        ...
# 643    00008084199                        ...
# 930    51079025520                        ...
# 48     00006353750                        ...
#
#                                               FDASPL_MOA  \
# 945                                                  NaN
# 946                                                  NaN
# 944                                                  NaN
# 18260   {Hydroxymethylglutaryl-CoA Reductase Inhibitors}
# 18252                                  {GABA A Agonists}
# 18262                                                NaN
# 18259                                                NaN
# 18266  {Cytochrome P450 2C9 Inhibitors, Cytochrome P4...
# 18267                           {Proton Pump Inhibitors}
# 18254                                  {GABA A Agonists}
# 18283                                                NaN
# 16710               {Cholinergic Muscarinic Antagonists}
# 16708                                                NaN
# 18299                             {Full Opioid Agonists}
# 18297                                                NaN
# 16836                                                NaN
# 18301                                  {GABA A Agonists}
# 16844                                                NaN
# 16843                                                NaN
# 16852                                                NaN
# 883                                                  NaN
# 16859                                                NaN
# 16857                                                NaN
# 16860                                                NaN
# 16862                                                NaN
# 16863                                                NaN
# 16868  {Adrenergic beta1-Antagonists, Adrenergic alph...
# 18250                           {Proton Pump Inhibitors}
# 18271                                                NaN
# 18277                   {Phosphodiesterase 3 Inhibitors}
# ...                                                  ...
# 10996         {Angiotensin-converting Enzyme Inhibitors}
# 10994                                                NaN
# 615                                                  NaN
# 9487                                                 NaN
# 9485                                                 NaN
# 606                    {Potassium Ion Exchange Activity}
# 604                        {Adrenergic beta-Antagonists}
# 602                  {Histamine H2 Receptor Antagonists}
# 608     {Hydroxymethylglutaryl-CoA Reductase Inhibitors}
# 642                        {Adrenergic beta-Antagonists}
# 633                                                  NaN
# 640    {Serotonin Uptake Inhibitors, Norepinephrine U...
# 635                                                  NaN
# 931                                                  NaN
# 616               {Thyroid Hormone Synthesis Inhibitors}
# 631                          {Cholinesterase Inhibitors}
# 614                                                  NaN
# 47                                                   NaN
# 617                               {Full Opioid Agonists}
# 620                                                  NaN
# 621                                                  NaN
# 624     {Hydroxymethylglutaryl-CoA Reductase Inhibitors}
# 609                                                  NaN
# 612               {Thyroid Hormone Synthesis Inhibitors}
# 636                                                  NaN
# 927                                                  NaN
# 926               {Thyroid Hormone Synthesis Inhibitors}
# 643                             {Proton Pump Inhibitors}
# 930                        {Adrenergic beta-Antagonists}
# 48                   {Histamine H2 Receptor Antagonists}
#
#                                                FDASPL_PE  \
# 945                                                  NaN
# 946                                                  NaN
# 944                                                  NaN
# 18260                                                NaN
# 18252                {Central Nervous System Depression}
# 18262                                                NaN
# 18259                                                NaN
# 18266                                                NaN
# 18267                                                NaN
# 18254                {Central Nervous System Depression}
# 18283  {Increased Prothrombin Activity, Reversed Anti...
# 16710                                                NaN
# 16708                                                NaN
# 18299                                                NaN
# 18297                                                NaN
# 16836                                                NaN
# 18301                {Central Nervous System Depression}
# 16844                                                NaN
# 16843                                                NaN
# 16852                                                NaN
# 883                                                  NaN
# 16859                                                NaN
# 16857                                                NaN
# 16860                                                NaN
# 16862              {Increased Diuresis at Loop of Henle}
# 16863                                                NaN
# 16868                                                NaN
# 18250                                                NaN
# 18271                                                NaN
# 18277                                                NaN
# ...                                                  ...
# 10996                                                NaN
# 10994                                                NaN
# 615                                                  NaN
# 9487               {Increased Diuresis at Loop of Henle}
# 9485                                                 NaN
# 606                                                  NaN
# 604                                                  NaN
# 602                                                  NaN
# 608                                                  NaN
# 642                                                  NaN
# 633                                                  NaN
# 640                                                  NaN
# 635                                                  NaN
# 931                {Increased Diuresis at Loop of Henle}
# 616                                                  NaN
# 631                                                  NaN
# 614                                                  NaN
# 47                                                   NaN
# 617                                                  NaN
# 620                                                  NaN
# 621                                                  NaN
# 624                                                  NaN
# 609                                                  NaN
# 612                                                  NaN
# 636                                                  NaN
# 927                                                  NaN
# 926                                                  NaN
# 643                                                  NaN
# 930                                                  NaN
# 48                                                   NaN
#
#                      FMTSME_TC  \
# 945                        NaN
# 946                        NaN
# 944                        NaN
# 18260                      NaN
# 18252                      NaN
# 18262                      NaN
# 18259                      NaN
# 18266  {Anti-arrhythmic Agent}
# 18267                      NaN
# 18254                      NaN
# 18283                      NaN
# 16710                      NaN
# 16708    {Antibacterial Agent}
# 18299                      NaN
# 18297                      NaN
# 16836                      NaN
# 18301                      NaN
# 16844                      NaN
# 16843                      NaN
# 16852                      NaN
# 883                        NaN
# 16859    {Antipsychotic Agent}
# 16857                      NaN
# 16860    {Antibacterial Agent}
# 16862                      NaN
# 16863                      NaN
# 16868                      NaN
# 18250                      NaN
# 18271                      NaN
# 18277                      NaN
# ...                        ...
# 10996                      NaN
# 10994                      NaN
# 615                        NaN
# 9487                       NaN
# 9485                       NaN
# 606                        NaN
# 604                        NaN
# 602                        NaN
# 608                        NaN
# 642                        NaN
# 633                        NaN
# 640                        NaN
# 635                        NaN
# 931                        NaN
# 616                        NaN
# 631                        NaN
# 614                        NaN
# 47                         NaN
# 617                        NaN
# 620                        NaN
# 621                        NaN
# 624                        NaN
# 609      {Antipsychotic Agent}
# 612                        NaN
# 636      {Antipsychotic Agent}
# 927      {Antipsychotic Agent}
# 926                        NaN
# 643                        NaN
# 930                        NaN
# 48                         NaN
#
#                                               MEDRT_CHEM  \
# 945                                                  NaN
# 946                                      {Senna Extract}
# 944                         {Dioctyl Sulfosuccinic Acid}
# 18260                                      {Simvastatin}
# 18252                                        {Pyridines}
# 18262                                       {Folic Acid}
# 18259                                    {Acetaminophen}
# 18266  {Fluoroquinolones, Ritonavir, Amiodarone, Cisa...
# 18267          {2-Pyridinylmethylsulfinylbenzimidazoles}
# 18254                                        {Pyridines}
# 18283                                      {Vitamin K 1}
# 16710                                   {Mandelic Acids}
# 16708                                       {Cephalexin}
# 18299                                         {Tramadol}
# 18297                                  {Phenazopyridine}
# 16836                       {Dioctyl Sulfosuccinic Acid}
# 18301                                        {Pyridines}
# 16844                                          {Aspirin}
# 16843                                        {Trazodone}
# 16852                               {Potassium Chloride}
# 883                                                  NaN
# 16859                                  {Benzodiazepines}
# 16857                                    {Acetaminophen}
# 16860                                       {Cephalexin}
# 16862                                     {Sulfonamides}
# 16863                               {Potassium Chloride}
# 16868                       {Propanolamines, Carbazoles}
# 18250          {2-Pyridinylmethylsulfinylbenzimidazoles}
# 18271                          {Sulfites, Phenylephrine}
# 18277                              {Milrinone, Amrinone}
# ...                                                  ...
# 10996                                        {Captopril}
# 10994                               {Potassium Chloride}
# 615                                                  NaN
# 9487                          {Furosemide, Sulfonamides}
# 9485                                {Potassium Chloride}
# 606                                       {Polystyrenes}
# 604                                         {Metoprolol}
# 602                                         {Ranitidine}
# 608                               {Atorvastatin Calcium}
# 642                                         {Metoprolol}
# 633                                            {Heparin}
# 640                          {Venlafaxine Hydrochloride}
# 635                                         {Lisinopril}
# 931                           {Furosemide, Sulfonamides}
# 616                                        {Methimazole}
# 631                                {Piperidines, Indans}
# 614                         {Dioctyl Sulfosuccinic Acid}
# 47                          {Dioctyl Sulfosuccinic Acid}
# 617                                          {Oxycodone}
# 620                                      {Acetaminophen}
# 621                                          {Mianserin}
# 624                               {Atorvastatin Calcium}
# 609                                {Quetiapine Fumarate}
# 612                                        {Methimazole}
# 636                                {Quetiapine Fumarate}
# 927                                {Quetiapine Fumarate}
# 926                                        {Methimazole}
# 643            {2-Pyridinylmethylsulfinylbenzimidazoles}
# 930                                         {Metoprolol}
# 48                                          {Famotidine}
#
#                                            MEDRT_DISEASE  \
# 945                                                  NaN
# 946                                {Colic, Constipation}
# 944    {Abdominal Pain, Drug Hypersensitivity, Nausea...
# 18260  {Hypercholesterolemia, Drug Hypersensitivity, ...
# 18252  {Drug Hypersensitivity, Sleep Initiation and M...
# 18262  {Anemia, Iron-Deficiency, Drug Hypersensitivit...
# 18259  {Drug Hypersensitivity, Glucosephosphate Dehyd...
# 18266  {Tachycardia, Supraventricular, Lactation, Bra...
# 18267  {Esophagitis, Drug Hypersensitivity, Zollinger...
# 18254  {Drug Hypersensitivity, Sleep Initiation and M...
# 18283  {Hypoprothrombinemias, Drug Hypersensitivity, ...
# 16710  {Dysuria, Drug Hypersensitivity, Myasthenia Gr...
# 16708  {Klebsiella Infections, Urinary Tract Infectio...
# 18299  {Opioid-Related Disorders, Drug Hypersensitivi...
# 18297  {Kidney Diseases, Liver Diseases, Pain, Urolog...
# 16836  {Abdominal Pain, Drug Hypersensitivity, Nausea...
# 18301  {Drug Hypersensitivity, Sleep Initiation and M...
# 16844  {Pain, Osteoarthritis, Ischemic Attack, Transi...
# 16843  {Depressive Disorder, Drug Hypersensitivity, S...
# 16852  {Drug Hypersensitivity, Renal Insufficiency, P...
# 883                                                  NaN
# 16859  {Psychotic Disorders, Drug Hypersensitivity, S...
# 16857  {Drug Hypersensitivity, Glucosephosphate Dehyd...
# 16860  {Klebsiella Infections, Urinary Tract Infectio...
# 16862  {Nephrotic Syndrome, Ascites, Anuria, Drug Hyp...
# 16863  {Drug Hypersensitivity, Renal Insufficiency, P...
# 16868  {Bradycardia, Sick Sinus Syndrome, Bronchial H...
# 18250  {Esophagitis, Drug Hypersensitivity, Zollinger...
# 18271  {Tachycardia, Supraventricular, Fissure in Ano...
# 18277  {Hypersensitivity, Drug-Related Side Effects a...
# ...                                                  ...
# 10996  {Ventricular Dysfunction, Left, Hyperaldostero...
# 10994  {Drug Hypersensitivity, Renal Insufficiency, P...
# 615                                                  NaN
# 9487   {Nephrotic Syndrome, Ascites, Anuria, Coma, Dr...
# 9485   {Drug Hypersensitivity, Renal Insufficiency, P...
# 606    {Drug Hypersensitivity, Hypernatremia, Hyperka...
# 604    {Tachycardia, Supraventricular, Sick Sinus Syn...
# 602    {Duodenal Ulcer, Drug Hypersensitivity, Zollin...
# 608    {Hypercholesterolemia, Drug Hypersensitivity, ...
# 642    {Tachycardia, Supraventricular, Sick Sinus Syn...
# 633    {Thrombocytopenia, Thrombophlebitis, Coronary ...
# 640    {Pain, Drug Hypersensitivity, Fatigue Syndrome...
# 635    {Ventricular Dysfunction, Left, Hyperaldostero...
# 931    {Nephrotic Syndrome, Ascites, Anuria, Coma, Dr...
# 616    {Lactation, Goiter, Thyroid Crisis, Drug Hyper...
# 631                {Alzheimer Disease, Hypersensitivity}
# 614    {Abdominal Pain, Drug Hypersensitivity, Nausea...
# 47     {Abdominal Pain, Drug Hypersensitivity, Nausea...
# 617    {Asthma, Drug Hypersensitivity, Pain, Postoper...
# 620    {Drug Hypersensitivity, Glucosephosphate Dehyd...
# 621         {Depressive Disorder, Drug Hypersensitivity}
# 624    {Hypercholesterolemia, Drug Hypersensitivity, ...
# 609    {Schizophrenia, Liver Diseases, Depressive Dis...
# 612    {Lactation, Goiter, Thyroid Crisis, Drug Hyper...
# 636    {Schizophrenia, Liver Diseases, Depressive Dis...
# 927    {Schizophrenia, Liver Diseases, Depressive Dis...
# 926    {Lactation, Goiter, Thyroid Crisis, Drug Hyper...
# 643    {Esophagitis, Drug Hypersensitivity, Zollinger...
# 930    {Tachycardia, Supraventricular, Sick Sinus Syn...
# 48     {Duodenal Ulcer, Urticaria, Drug Hypersensitiv...
#
#                                                MEDRT_MOA  \
# 945                                                  NaN
# 946          {Unknown Cellular or Molecular Interaction}
# 944                                {Surfactant Activity}
# 18260   {Hydroxymethylglutaryl-CoA Reductase Inhibitors}
# 18252               {GABA A Modulators, GABA A Agonists}
# 18262                              {Enzyme Interactions}
# 18259               {Prostaglandin Receptor Antagonists}
# 18266  {Potassium Channel Interactions, Adrenergic be...
# 18267                           {Proton Pump Inhibitors}
# 18254               {GABA A Modulators, GABA A Agonists}
# 18283        {Unknown Cellular or Molecular Interaction}
# 16710               {Cholinergic Muscarinic Antagonists}
# 16708                                {Enzyme Inhibitors}
# 18299                             {Full Opioid Agonists}
# 18297        {Unknown Cellular or Molecular Interaction}
# 16836                              {Surfactant Activity}
# 18301               {GABA A Modulators, GABA A Agonists}
# 16844                        {Cyclooxygenase Inhibitors}
# 16843  {Histamine H1 Receptor Antagonists, Serotonin ...
# 16852         {Electrolyte Activity, Acid-Base Activity}
# 883                                                  NaN
# 16859  {Dopamine Antagonists, Adrenergic alpha-Antago...
# 16857               {Prostaglandin Receptor Antagonists}
# 16860                                {Enzyme Inhibitors}
# 16862   {Sodium Potassium Chloride Symporter Inhibitors}
# 16863         {Electrolyte Activity, Acid-Base Activity}
# 16868  {Adrenergic beta1-Antagonists, Adrenergic alph...
# 18250                           {Proton Pump Inhibitors}
# 18271                        {Adrenergic alpha-Agonists}
# 18277                   {Phosphodiesterase 3 Inhibitors}
# ...                                                  ...
# 10996         {Angiotensin-converting Enzyme Inhibitors}
# 10994         {Electrolyte Activity, Acid-Base Activity}
# 615                                                  NaN
# 9487    {Sodium Potassium Chloride Symporter Inhibitors}
# 9485          {Electrolyte Activity, Acid-Base Activity}
# 606    {Potassium Ion Exchange Activity, Sodium-Potas...
# 604                       {Adrenergic beta1-Antagonists}
# 602                  {Histamine H2 Receptor Antagonists}
# 608     {Hydroxymethylglutaryl-CoA Reductase Inhibitors}
# 642                       {Adrenergic beta1-Antagonists}
# 633       {Antithrombin Activators, Thrombin Inhibitors}
# 640    {Serotonin Uptake Inhibitors, Monoamine Oxidas...
# 635           {Angiotensin-converting Enzyme Inhibitors}
# 931     {Sodium Potassium Chloride Symporter Inhibitors}
# 616    {Thyroid Hormone Synthesis Inhibitors, Protein...
# 631                          {Cholinesterase Inhibitors}
# 614                                {Surfactant Activity}
# 47                                 {Surfactant Activity}
# 617                               {Full Opioid Agonists}
# 620                 {Prostaglandin Receptor Antagonists}
# 621    {Adrenergic alpha1-Antagonists, Monoamine Oxid...
# 624     {Hydroxymethylglutaryl-CoA Reductase Inhibitors}
# 609    {Histamine H1 Receptor Antagonists, Dopamine A...
# 612    {Thyroid Hormone Synthesis Inhibitors, Protein...
# 636    {Histamine H1 Receptor Antagonists, Dopamine A...
# 927    {Histamine H1 Receptor Antagonists, Dopamine A...
# 926    {Thyroid Hormone Synthesis Inhibitors, Protein...
# 643                             {Proton Pump Inhibitors}
# 930                       {Adrenergic beta1-Antagonists}
# 48                   {Histamine H2 Receptor Antagonists}
#
#                                                 MEDRT_PE  \
# 945                                                  NaN
# 946    {Increased Large Intestinal Muscle Tone, Incre...
# 944    {Stimulation Large Intestine Fluid/Electrolyte...
# 18260                                                NaN
# 18252  {Decreased Central Nervous System Organized El...
# 18262                     {Cellular Activity Alteration}
# 18259  {Hypothalamic Endocrine Activity Alteration, P...
# 18266  {Negative Chronotropy, Ventricular Repolarizat...
# 18267                {Inhibition Gastric Acid Secretion}
# 18254  {Decreased Central Nervous System Organized El...
# 18283  {Increased Prothrombin Activity, Reversed Anti...
# 16710  {Decreased Smooth Muscle Acetylcholine Activit...
# 16708           {Decreased Cell Wall Synthesis & Repair}
# 18299  {Decreased Organized Electrical Activity, Incr...
# 18297  {Analgesia, Renal/Urological Activity Alteration}
# 16836  {Stimulation Large Intestine Fluid/Electrolyte...
# 18301  {Decreased Central Nervous System Organized El...
# 16844  {Decreased Platelet Activating Factor Producti...
# 16843  {Increased Central Nervous System Serotonin Ac...
# 16852  {Increased Insulin Secretion, Organized Electr...
# 883                                                  NaN
# 16859  {Decreased Acetylcholine Activity, Decreased H...
# 16857  {Hypothalamic Endocrine Activity Alteration, P...
# 16860           {Decreased Cell Wall Synthesis & Repair}
# 16862  {Increased Loop of Henle K+ Excretion, Decreas...
# 16863  {Increased Insulin Secretion, Organized Electr...
# 16868  {Arterial Vasodilation, Negative Inotropy, Neg...
# 18250                {Inhibition Gastric Acid Secretion}
# 18271  {Decreased Nasal and Sinus Secretions, Conjunc...
# 18277  {Positive Inotropy, Increased Blood Pressure, ...
# ...                                                  ...
# 10996  {Decreased Intravascular Volume, Decreased Bra...
# 10994  {Increased Insulin Secretion, Organized Electr...
# 615                                                  NaN
# 9487   {Increased Loop of Henle K+ Excretion, Decreas...
# 9485   {Increased Insulin Secretion, Organized Electr...
# 606                       {Increased Renal K+ Excretion}
# 604    {Negative Inotropy, Negative Chronotropy, Decr...
# 602    {Inhibition Gastric Acid Secretion, Decreased ...
# 608                    {Decreased Cholesterol Synthesis}
# 642    {Negative Inotropy, Negative Chronotropy, Decr...
# 633              {Decreased Coagulation Factor Activity}
# 640    {Increased Central Nervous System Serotonin Ac...
# 635    {Decreased Intravascular Volume, Decreased Bra...
# 931    {Increased Loop of Henle K+ Excretion, Decreas...
# 616    {Decreased Iodine Organification, Decreased Th...
# 631    {Increased Central Nervous System Acetylcholin...
# 614    {Stimulation Large Intestine Fluid/Electrolyte...
# 47     {Stimulation Large Intestine Fluid/Electrolyte...
# 617    {Analgesia, Decreased Organized Electrical Act...
# 620    {Hypothalamic Endocrine Activity Alteration, P...
# 621    {Increased Serotonin Activity, Increased Norep...
# 624                    {Decreased Cholesterol Synthesis}
# 609    {Decreased Histamine Activity, Decreased Dopam...
# 612    {Decreased Iodine Organification, Decreased Th...
# 636    {Decreased Histamine Activity, Decreased Dopam...
# 927    {Decreased Histamine Activity, Decreased Dopam...
# 926    {Decreased Iodine Organification, Decreased Th...
# 643                  {Inhibition Gastric Acid Secretion}
# 930    {Negative Inotropy, Negative Chronotropy, Decr...
# 48     {Inhibition Gastric Acid Secretion, Decreased ...
#
#                                     MEDRT_PK  \
# 945                                      NaN
# 946                                      NaN
# 944                                      NaN
# 18260                                    NaN
# 18252                                    NaN
# 18262                                    NaN
# 18259  {Renal Excretion, Hepatic Metabolism}
# 18266                                    NaN
# 18267                   {Hepatic Metabolism}
# 18254                                    NaN
# 18283                                    NaN
# 16710                                    NaN
# 16708                                    NaN
# 18299                                    NaN
# 18297                                    NaN
# 16836                                    NaN
# 18301                                    NaN
# 16844  {Renal Excretion, Hepatic Metabolism}
# 16843                                    NaN
# 16852                                    NaN
# 883                                      NaN
# 16859                                    NaN
# 16857  {Renal Excretion, Hepatic Metabolism}
# 16860                                    NaN
# 16862  {Renal Excretion, Hepatic Metabolism}
# 16863                                    NaN
# 16868                                    NaN
# 18250                   {Hepatic Metabolism}
# 18271                                    NaN
# 18277                                    NaN
# ...                                      ...
# 10996                                    NaN
# 10994                                    NaN
# 615                                      NaN
# 9487   {Renal Excretion, Hepatic Metabolism}
# 9485                                     NaN
# 606                                      NaN
# 604                     {Hepatic Metabolism}
# 602    {Renal Excretion, Hepatic Metabolism}
# 608                     {Hepatic Metabolism}
# 642                     {Hepatic Metabolism}
# 633                                      NaN
# 640                                      NaN
# 635                                      NaN
# 931    {Renal Excretion, Hepatic Metabolism}
# 616                                      NaN
# 631                                      NaN
# 614                                      NaN
# 47                                       NaN
# 617                                      NaN
# 620    {Renal Excretion, Hepatic Metabolism}
# 621                                      NaN
# 624                     {Hepatic Metabolism}
# 609                                      NaN
# 612                                      NaN
# 636                                      NaN
# 927                                      NaN
# 926                                      NaN
# 643                     {Hepatic Metabolism}
# 930                     {Hepatic Metabolism}
# 48                                       NaN
#
#                                              MESH_MESHPA  \
# 945                                                  NaN
# 946                                         {Cathartics}
# 944                                                  NaN
# 18260  {Hypolipidemic Agents, Hydroxymethylglutaryl-C...
# 18252                                                NaN
# 18262                    {Hematinics, Vitamin B Complex}
# 18259           {Antipyretics, Analgesics, Non-Narcotic}
# 18266  {Cytochrome P-450 CYP3A Inhibitors, Sodium Cha...
# 18267                                                NaN
# 18254                                                NaN
# 18283                {Antifibrinolytic Agents, Vitamins}
# 16710  {Parasympatholytics, Muscarinic Antagonists, U...
# 16708                            {Anti-Bacterial Agents}
# 18299                    {Narcotics, Analgesics, Opioid}
# 18297                                                NaN
# 16836                                                NaN
# 18301                                                NaN
# 16844  {Platelet Aggregation Inhibitors, Cyclooxygena...
# 16843  {Antidepressive Agents, Second-Generation, Ant...
# 16852                                                NaN
# 883                                                  NaN
# 16859                                                NaN
# 16857           {Antipyretics, Analgesics, Non-Narcotic}
# 16860                            {Anti-Bacterial Agents}
# 16862                                                NaN
# 16863                                                NaN
# 16868                                                NaN
# 18250                                                NaN
# 18271  {Cardiotonic Agents, Sympathomimetics, Adrener...
# 18277  {Phosphodiesterase 3 Inhibitors, Cardiotonic A...
# ...                                                  ...
# 10996  {Angiotensin-Converting Enzyme Inhibitors, Ant...
# 10994                                                NaN
# 615                                                  NaN
# 9487   {Diuretics, Sodium Potassium Chloride Symporte...
# 9485                                                 NaN
# 606                                   {Chelating Agents}
# 604    {Antihypertensive Agents, Adrenergic beta-1 Re...
# 602        {Anti-Ulcer Agents, Histamine H2 Antagonists}
# 608    {Hydroxymethylglutaryl-CoA Reductase Inhibitor...
# 642    {Antihypertensive Agents, Adrenergic beta-1 Re...
# 633                {Fibrinolytic Agents, Anticoagulants}
# 640    {Antidepressive Agents, Second-Generation, Ser...
# 635    {Angiotensin-Converting Enzyme Inhibitors, Ant...
# 931    {Diuretics, Sodium Potassium Chloride Symporte...
# 616                                 {Antithyroid Agents}
# 631                                                  NaN
# 614                                                  NaN
# 47                                                   NaN
# 617                      {Narcotics, Analgesics, Opioid}
# 620             {Antipyretics, Analgesics, Non-Narcotic}
# 621                                                  NaN
# 624    {Hydroxymethylglutaryl-CoA Reductase Inhibitor...
# 609                               {Antipsychotic Agents}
# 612                                 {Antithyroid Agents}
# 636                               {Antipsychotic Agents}
# 927                               {Antipsychotic Agents}
# 926                                 {Antithyroid Agents}
# 643                                                  NaN
# 930    {Antihypertensive Agents, Adrenergic beta-1 Re...
# 48         {Anti-Ulcer Agents, Histamine H2 Antagonists}
#
#                                                    VA_VA
# 945                                                  NaN
# 946                                {STIMULANT LAXATIVES}
# 944                                     {STOOL SOFTENER}
# 18260                               {ANTILIPEMIC AGENTS}
# 18252                        {SEDATIVES/HYPNOTICS,OTHER}
# 18262                            {FOLIC ACID/LEUCOVORIN}
# 18259                            {NON-OPIOID ANALGESICS}
# 18266                                  {ANTIARRHYTHMICS}
# 18267                        {GASTRIC MEDICATIONS,OTHER}
# 18254                        {SEDATIVES/HYPNOTICS,OTHER}
# 18283                                     {PHYTONADIONE}
# 16710                           {ANTISPASMODICS,URINARY}
# 16708                     {CEPHALOSPORIN 1ST GENERATION}
# 18299                                {OPIOID ANALGESICS}
# 18297                               {ANALGESICS,URINARY}
# 16836                                   {STOOL SOFTENER}
# 18301                        {SEDATIVES/HYPNOTICS,OTHER}
# 16844                            {NON-OPIOID ANALGESICS}
# 16843                            {ANTIDEPRESSANTS,OTHER}
# 16852                                        {POTASSIUM}
# 883                                                  NaN
# 16859                             {ANTIPSYCHOTICS,OTHER}
# 16857                            {NON-OPIOID ANALGESICS}
# 16860                     {CEPHALOSPORIN 1ST GENERATION}
# 16862                                   {LOOP DIURETICS}
# 16863                                        {POTASSIUM}
# 16868                            {BETA BLOCKERS/RELATED}
# 18250                        {GASTRIC MEDICATIONS,OTHER}
# 18271                   {SYMPATHOMIMETICS (ADRENERGICS)}
# 18277                      {CARDIOVASCULAR AGENTS,OTHER}
# ...                                                  ...
# 10996                                   {ACE INHIBITORS}
# 10994                                        {POTASSIUM}
# 615                                                  NaN
# 9487                                    {LOOP DIURETICS}
# 9485                                         {POTASSIUM}
# 606    {ANTIDOTES,DETERRENTS,AND POISON CONTROL EXCHA...
# 604                              {BETA BLOCKERS/RELATED}
# 602            {HISTAMINE ANTAGONISTS, H. PYLORI AGENTS}
# 608                                 {ANTILIPEMIC AGENTS}
# 642                              {BETA BLOCKERS/RELATED}
# 633                                     {ANTICOAGULANTS}
# 640                              {ANTIDEPRESSANTS,OTHER}
# 635                                     {ACE INHIBITORS}
# 931                                     {LOOP DIURETICS}
# 616                                 {ANTITHYROID AGENTS}
# 631                              {CNS MEDICATIONS,OTHER}
# 614                                     {STOOL SOFTENER}
# 47                                      {STOOL SOFTENER}
# 617                                  {OPIOID ANALGESICS}
# 620                              {NON-OPIOID ANALGESICS}
# 621                              {ANTIDEPRESSANTS,OTHER}
# 624                                 {ANTILIPEMIC AGENTS}
# 609                               {ANTIPSYCHOTICS,OTHER}
# 612                                 {ANTITHYROID AGENTS}
# 636                               {ANTIPSYCHOTICS,OTHER}
# 927                               {ANTIPSYCHOTICS,OTHER}
# 926                                 {ANTITHYROID AGENTS}
# 643                          {GASTRIC MEDICATIONS,OTHER}
# 930                              {BETA BLOCKERS/RELATED}
# 48                               {HISTAMINE ANTAGONISTS}
#
# [7272 rows x 29 columns]
